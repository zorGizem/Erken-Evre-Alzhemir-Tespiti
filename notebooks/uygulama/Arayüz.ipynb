# %% [markdown]
# <a href="https://colab.research.google.com/github/zorGizem/Erken-Evre-Alzhemir-Tespiti/blob/main/notebooks/uygulama/Aray%C3%BCz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Numpy, Scipy ve Pandas sürümlerini sabitle
# !pip install -q "numpy==1.26.4" "scipy==1.12.0" "pandas==2.2.2"

# Sistem aracını kur
# !apt-get install -y dcm2niix -q

# Görüntü işleme ve arayüz kütüphanelerini kur
# !pip install -q antspyx nibabel nilearn gradio

# HD-BET ve diğer gerekli derin öğrenme bağımlılıklarını kur
# !git clone https://github.com/MIC-DKFZ/HD-BET
# %cd HD-BET
# !pip install -q -e .
# %cd ..
# !pip install -q SimpleITK batchgenerators acvl_utils dynamic_network_architectures nnunetv2

# Kurulumlar sonrası Numpy'ı tekrar sabitle
# !pip install -q "numpy==1.26.4"

print("KURULUM BİTTİ — Lütfen 'Çalışma zamanı -> Oturumu yeniden başlat' işlemini yapın.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 139.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 71.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# ===== 1. HÜCRE: DRIVE BAĞLANTISI VE KURULUMLAR =====
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# ===== 2. HÜCRE: ARAYÜZÜN BAŞLATILMASI =====
import sys
import importlib

# 1) Uygulama modüllerinizin bulunduğu klasör yolunu sisteme ekleyin
sys.path.append('/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Kodlar/notebooks/uygulama')

# 2) Önbelleği temizleyip arayüz modülünü içe aktarın (Koddaki değişikliklerin anında yansıması için)
importlib.invalidate_caches()
import app_gradio
importlib.reload(app_gradio)
from app_gradio import build_app

print("Arayüz modülü yüklendi ✓")

# 3) MNI beyin şablonu ve eğitilmiş modellerin yolu ile uygulamayı inşa edin
app = build_app(
    mni_template_path='/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/mni152_brain_1mm.nii.gz',
    model_klasoru='/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_05_16_27'
)

# 4) Arayüzü paylaşılabilir link ile (share=True) başlatın
app.launch(debug=True, share=True)
# Out:
# Arayüz modülü yüklendi ✓
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://23ce5f6443fc38cf55.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://23ce5f6443fc38cf55.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# [pipeline] Çalışma klasörü: /tmp/subject_d1bbykkc
# [pipeline] ADIM 1 OK: DICOM -> NIfTI (subject.nii.gz)
# [pipeline] ADIM 2 OK: N4 Bias Field Correction
# [pipeline] ADIM 3 OK: Skull Stripping (HD-BET)
# [pipeline] ADIM 4 OK: MNI Registration (beyin + maske)
# [pipeline] ADIM 5 OK: Z-Score Normalizasyon
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
