# %% [markdown]
# <a href="https://colab.research.google.com/github/zorGizem/Erken-Evre-Alzhemir-Tespiti/blob/main/notebooks/kod/Perplane_weight_decay%3D7e_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
import torchvision.transforms as transforms
import nibabel as nib
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import (classification_report, confusion_matrix,
                             accuracy_score, precision_recall_fscore_support)

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(SEED)

print(f"PyTorch: {torch.__version__}")
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Cihaz  : {DEVICE}")
if torch.cuda.is_available():
    print(f"GPU    : {torch.cuda.get_device_name(0)}")
print(f"Seed   : {SEED}")
# Out:
# PyTorch: 2.11.0+cu128
# Cihaz  : cuda
# GPU    : NVIDIA A100-SXM4-40GB
# Seed   : 42

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import shutil, os

drive_path = '/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/Slice_v2/'
zip_cn   = drive_path + 'Slice_CN.zip'
zip_emci = drive_path + 'Slice_EMCI.zip'

local_dir = '/content/dataset'
os.makedirs(local_dir, exist_ok=True)

if not os.path.exists(os.path.join(local_dir, 'Slice_CN')):
    print("Slice_CN aciliyor...")
    shutil.unpack_archive(zip_cn, local_dir)
    print("  Tamamlandi.")
else:
    print("Slice_CN zaten var.")

if not os.path.exists(os.path.join(local_dir, 'Slice_EMCI')):
    print("Slice_EMCI aciliyor...")
    shutil.unpack_archive(zip_emci, local_dir)
    print("  Tamamlandi.")
else:
    print("Slice_EMCI zaten var.")

print("Veri hazir.")
# Out:
# Slice_CN aciliyor...

# %%
import zipfile, os

# Test zip'lerinin Drive'daki yeri
test_zip_cn   = '/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/Test/Slice/Slice_CN.zip'
test_zip_emci = '/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/Test/Slice/Slice_EMCI.zip'

# Yerele acilacak hedef
os.makedirs('/content/dataset_test', exist_ok=True)

for zip_yolu in [test_zip_cn, test_zip_emci]:
    with zipfile.ZipFile(zip_yolu, 'r') as z:
        z.extractall('/content/dataset_test')
    print(f"Acildi: {zip_yolu}")

# Ne cikti, kontrol et
print("\nIcerik:")
for d in sorted(os.listdir('/content/dataset_test')):
    print("  ", d)
# Out:
# Acildi: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/Test/Slice/Slice_CN.zip
# Acildi: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/Test/Slice/Slice_EMCI.zip
#
# Icerik:
#    Slice_CN
#    Slice_EMCI

# %%
import datetime, os

zaman_damgasi = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M")
deney_adi = f"DenseNet_PerPlane_Ensemble_YOL2_{zaman_damgasi}"
ANA_KLASOR = f'/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/{deney_adi}'

os.makedirs(ANA_KLASOR, exist_ok=True)
print(f"Ana klasor: {ANA_KLASOR}")

CONFIG = {
    # --- EGITIM verisi (train + validation) ---
    "kaynak_CN"     : '/content/dataset/Slice_CN',
    "kaynak_EMCI"   : '/content/dataset/Slice_EMCI',

    # --- IZOLE TEST verisi (egitime HIC girmez) ---
    "kaynak_CN_test"   : '/content/dataset_test/Slice_CN',
    "kaynak_EMCI_test" : '/content/dataset_test/Slice_EMCI',

    "ana_klasor"    : ANA_KLASOR,

    "k_fold"        : 5,
    "batch_size"    : 16,
    "epoch"         : 80,

    # --- OVERFIT DUZELTMELERI (degisen degerler) ---
    "lr_finetune"   : 2e-4,    # 5e-4 -> 2e-4  (backbone yavaslatildi)
    "lr_head"       : 1e-3,    # 5e-3 -> 1e-3  (kafa cok hizliydi, dustur)
    "dropout"       : 0.6,     # 0.5 -> 0.6
    "weight_decay"  : 7e-4,    # 1e-4 -> 5e-4  (en etkili overfit kaldiraci)
    "patience"      : 12,      # 15 -> 12

    "img_size"      : 224,
    "slice_per_plane": 10,
    "val_orani"     : 0.15,
    "num_workers"   : 8,
    "min_lr"        : 1e-6,

    "use_class_weights" : True,
    "label_smoothing"   : 0.1,
    "grad_clip_norm"    : 1.0,
}

print(f"Batch size    : {CONFIG['batch_size']}")
print(f"Train/Val     : %{int((1-CONFIG['val_orani'])*100)} / %{int(CONFIG['val_orani']*100)}")
print(f"LR finetune   : {CONFIG['lr_finetune']}  (dusuruldu)")
print(f"LR head       : {CONFIG['lr_head']}  (dusuruldu)")
print(f"Dropout       : {CONFIG['dropout']}  |  Weight Decay: {CONFIG['weight_decay']}")
print(f"Patience      : {CONFIG['patience']}")
print("\nNOT: Test klasor yollarini (kaynak_CN_test / kaynak_EMCI_test) kendin guncelle.")
# Out:
# Ana klasor: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_11_09_02
# Batch size    : 16
# Train/Val     : %85 / %15
# LR finetune   : 0.0002  (dusuruldu)
# LR head       : 0.001  (dusuruldu)
# Dropout       : 0.6  |  Weight Decay: 0.0007
# Patience      : 12
#
# NOT: Test klasor yollarini (kaynak_CN_test / kaynak_EMCI_test) kendin guncelle.

# %%
def dosya_dan_duzlem_cikar(dosya_adi):
    ad_lower = dosya_adi.lower()
    if 'sagital' in ad_lower or 'sagittal' in ad_lower:
        return 'sagital'
    elif 'aksiyal' in ad_lower or 'axial' in ad_lower:
        return 'aksiyal'
    elif 'koronal' in ad_lower or 'coronal' in ad_lower:
        return 'koronal'
    return None


def veri_listesi_olustur(config):
    veriler = []
    for sinif, kaynak in [(0, config["kaynak_CN"]), (1, config["kaynak_EMCI"])]:
        if not os.path.exists(kaynak):
            print(f"Klasor bulunamadi: {kaynak}")
            continue
        for hasta_id in sorted(os.listdir(kaynak)):
            hasta_yol = os.path.join(kaynak, hasta_id)
            if not os.path.isdir(hasta_yol):
                continue
            for seans_id in sorted(os.listdir(hasta_yol)):
                seans_yol = os.path.join(hasta_yol, seans_id)
                if not os.path.isdir(seans_yol):
                    continue
                seans_dict = {
                    'hasta_id': hasta_id, 'seans_id': seans_id,
                    'etiket': sinif,
                    'sagital': [], 'aksiyal': [], 'koronal': []
                }
                for f in sorted(os.listdir(seans_yol)):
                    if f.endswith('.nii.gz') or f.endswith('.nii'):
                        duzlem = dosya_dan_duzlem_cikar(f)
                        if duzlem:
                            seans_dict[duzlem].append(os.path.join(seans_yol, f))
                if (len(seans_dict['sagital']) == config["slice_per_plane"] and
                    len(seans_dict['aksiyal']) == config["slice_per_plane"] and
                    len(seans_dict['koronal']) == config["slice_per_plane"]):
                    veriler.append(seans_dict)
    return veriler


tum_veriler = veri_listesi_olustur(CONFIG)
n_cn   = sum(1 for x in tum_veriler if x['etiket'] == 0)
n_emci = sum(1 for x in tum_veriler if x['etiket'] == 1)
print(f"Toplam seans : {len(tum_veriler)}")
print(f"  CN seans   : {n_cn}")
print(f"  EMCI seans : {n_emci}")
print(f"  Hasta sayisi: {len(set(x['hasta_id'] for x in tum_veriler))}")
# Out:
# Klasor bulunamadi: /content/dataset/Slice_CN
# Klasor bulunamadi: /content/dataset/Slice_EMCI
# Toplam seans : 0
#   CN seans   : 0
#   EMCI seans : 0
#   Hasta sayisi: 0

# %%
class SinglePlaneDataset(Dataset):
    """
    Tek bir duzlem icin Dataset.

    duzlem parametresi: 'sagital', 'aksiyal' veya 'koronal'
    Her __getitem__ sadece o duzlemin slice'larini dondurur.

    Pipeline (Defter 1 ile ayni):
      nibabel yukle → 3 kanala genislet → ToTensor + Resize → ImageNet normalize
    """

    IMAGENET_MEAN = [0.485, 0.456, 0.406]
    IMAGENET_STD  = [0.229, 0.224, 0.225]

    def __init__(self, seans_listesi, duzlem, img_size=224):
        assert duzlem in ('sagital', 'aksiyal', 'koronal'),             f"Gecersiz duzlem: {duzlem}"
        self.seans_listesi = seans_listesi
        self.duzlem = duzlem
        self.img_size = img_size

        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Resize((img_size, img_size), antialias=True),
            transforms.Normalize(mean=self.IMAGENET_MEAN, std=self.IMAGENET_STD),
        ])

    def __len__(self):
        return len(self.seans_listesi)

    def _slice_yukle(self, yol):
        img = nib.load(yol).get_fdata().astype(np.float32).squeeze()
        img = np.stack([img]*3, axis=-1)
        return self.transform(img)

    def __getitem__(self, idx):
        seans = self.seans_listesi[idx]
        seans_id = f"{seans['hasta_id']}_{seans['seans_id']}"
        slices  = torch.stack([self._slice_yukle(y) for y in seans[self.duzlem]])
        etiket  = torch.tensor(seans['etiket'], dtype=torch.long)
        return seans_id, slices, etiket


def loader_olustur(seans_listesi, duzlem, config, shuffle=True):
    """Tek duzlem icin DataLoader olustur."""
    dataset = SinglePlaneDataset(seans_listesi, duzlem, img_size=config['img_size'])
    return DataLoader(
        dataset,
        batch_size=config['batch_size'],
        shuffle=shuffle,
        num_workers=config['num_workers'],
        pin_memory=True,
        worker_init_fn=seed_worker if shuffle else None,
        generator=g if shuffle else None
    )

print("SinglePlaneDataset hazir (ImageNet normalize).")
print("  Kullanim: SinglePlaneDataset(seans_listesi, 'sagital')")
# Out:
# SinglePlaneDataset hazir (ImageNet normalize).
#   Kullanim: SinglePlaneDataset(seans_listesi, 'sagital')

# %%
class SinglePlaneModel(nn.Module):
    """
    Tek duzlem modeli — DenseNet121.

    Akis:
      10 slice → DenseNet → 10 feature → Mean Pooling → 1 vektor (1024)
              → Classifier → 2 sinif (CN veya EMCI)

    Defter 1'den farki:
      - Sadece 1 backbone (3 degil)
      - Fusion yok, concat yok
      - Her duzlem bu modelin bir kopyasini alir ve bagımsiz egitilir
    """
    def __init__(self, dropout_rate=0.5, hidden_dim=256):
        super().__init__()

        # DenseNet backbone (Defter 1 ile ayni freeze stratejisi)
        backbone = models.densenet121(weights=models.DenseNet121_Weights.IMAGENET1K_V1)
        for param in backbone.parameters():
            param.requires_grad = False
        for param in backbone.features.denseblock4.parameters():
            param.requires_grad = True
        for param in backbone.features.norm5.parameters():
            param.requires_grad = True
        backbone.classifier = nn.Identity()
        self.backbone = backbone

        feature_dim = 1024
        self.feat_dim = feature_dim

        # Siniflandirici
        self.classifier = nn.Sequential(
            nn.Linear(feature_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, 2)
        )

    def forward(self, slices):
        """
        slices: (B, S, C, H, W)  — B:batch, S:10 slice, C:3, H:224, W:224
        return: (B, 2)            — CN/EMCI logits
        """
        B, S, C, H, W = slices.shape
        slices_flat = slices.view(B * S, C, H, W)          # (B*S, C, H, W)
        features_flat = self.backbone(slices_flat)          # (B*S, 1024)
        features = features_flat.view(B, S, -1)            # (B, S, 1024)
        pooled   = features.mean(dim=1)                    # (B, 1024) — mean pool
        logits   = self.classifier(pooled)                 # (B, 2)
        return logits


def model_olustur(dropout_rate=0.5, hidden_dim=256, duzlem_adi='?'):
    model = SinglePlaneModel(dropout_rate=dropout_rate, hidden_dim=hidden_dim)
    total    = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"[{duzlem_adi}] Toplam param   : {total:,}")
    print(f"[{duzlem_adi}] Egitilen param : {trainable:,} ({100*trainable/total:.2f}%)")
    print(f"[{duzlem_adi}] Dropout        : {dropout_rate}")
    return model.to(DEVICE)

# Test
print("Model olusturuluyor (test)...")
_t = model_olustur(0.5, 256, 'TEST')
del _t; torch.cuda.empty_cache()
print("SinglePlaneModel hazir.")
# Out:
# Model olusturuluyor (test)...
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 169MB/s]
# [TEST] Toplam param   : 7,216,770
# [TEST] Egitilen param : 2,423,042 (33.58%)
# [TEST] Dropout        : 0.5
# SinglePlaneModel hazir.

# %%
def degerlendir(model, loader, kayip_fn=None):
    """Tek duzlem modeli icin degerlendirme."""
    model.eval()
    y_true, y_pred, probs_list = [], [], []
    total_loss, n_batches = 0.0, 0

    with torch.no_grad():
        for _, slices, lbls in loader:
            slices = slices.to(DEVICE)
            lbls   = lbls.to(DEVICE)
            logits = model(slices)
            if kayip_fn is not None:
                total_loss += kayip_fn(logits, lbls).item()
                n_batches += 1
            probs = torch.softmax(logits, dim=1)
            preds = logits.argmax(dim=1)
            y_true.extend(lbls.cpu().numpy().tolist())
            y_pred.extend(preds.cpu().numpy().tolist())
            probs_list.extend(probs.cpu().numpy().tolist())

    avg_loss = total_loss / n_batches if n_batches > 0 else 0.0
    return y_true, y_pred, avg_loss, probs_list

print("Degerlendirme fonksiyonu hazir.")
# Out:
# Degerlendirme fonksiyonu hazir.

# %%
from sklearn.metrics import f1_score

class EarlyStopping:
    """Macro-F1 takip eder (iki sinifi da esit onemser).

    val_loss yerine macro-F1'e bakar; boylece bir sinifi (ornegin CN)
    ihmal eden 'her seye EMCI de' tarzi modeller kaydedilmez.
    Geri uyumluluk icin val_loss da saklanir ama karar macro-F1 ile verilir.
    """
    def __init__(self, patience=12, path='best.pth'):
        self.patience    = patience
        self.path        = path
        self.counter     = 0
        self.best_score  = -1.0      # macro-F1 (yuksek = iyi)
        self.best_loss   = float('inf')
        self.best_acc    = -1.0
        self.early_stop  = False

    def __call__(self, macro_f1, val_loss, val_acc, model):
        if macro_f1 > self.best_score:
            self.best_score = macro_f1
            self.best_loss  = val_loss
            self.best_acc   = val_acc
            torch.save(model.state_dict(), self.path)
            self.counter = 0
            return True
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
            return False

print("EarlyStopping hazir (MACRO-F1 based).")
# Out:
# EarlyStopping hazir (MACRO-F1 based).

# %%
def duzlem_egit(veriler, duzlem, config, kayit_klasoru):
    """
    Tek bir duzlem icin 5-fold egitim — SADECE train/val.

    >>> Test seti bu fonksiyona HIC girmez. <<<
    Test seti disarida, izole tutulur ve yalniz en son hucrede
    birlesik ensemble uzerinden degerlendirilir.

    Her fold:
      - Hastalar bazinda %85 train / %15 val (her fold farkli random_state,
        boylece 5 farkli model -> ensemble uyeleri).
      - Model secimi val_loss uzerinden (EarlyStopping).
      - Fold sonunda en iyi model VALIDATION uzerinde raporlanir
        (accuracy, precision, recall, F1, per-class F1).
      - Model .pth olarak kaydedilir: '{duzlem}_fold_{fold}.pth'

    Dondurur:
      fold_results: her fold icin VALIDATION metrikleri
    """
    os.makedirs(kayit_klasoru, exist_ok=True)
    print(f"\n{'='*70}")
    print(f"DUZLEM: {duzlem.upper()}")
    print(f"Klasor: {kayit_klasoru}")
    print(f"{'='*70}")

    unique_pats = sorted(set(x['hasta_id'] for x in veriler))
    fold_results = []
    csv_yolu = os.path.join(kayit_klasoru, 'deney_sonuclari.csv')

    for fold in range(1, config['k_fold'] + 1):
        # Hastalar bazinda %85 train / %15 val (fold'a gore degisen seed)
        tr_ids, val_ids = train_test_split(
            unique_pats, test_size=config['val_orani'],
            random_state=SEED + fold
        )

        tr_seans  = [x for x in veriler if x['hasta_id'] in set(tr_ids)]
        val_seans = [x for x in veriler if x['hasta_id'] in set(val_ids)]

        print(f"\n{'='*70}\nFOLD {fold} [{duzlem.upper()}]")
        print(f"  Train: {len(tr_ids)} hasta / {len(tr_seans)} seans")
        print(f"  Val  : {len(val_ids)} hasta / {len(val_seans)} seans")

        for set_adi, set_data in [('Train', tr_seans), ('Val', val_seans)]:
            n_cn   = sum(1 for x in set_data if x['etiket'] == 0)
            n_emci = sum(1 for x in set_data if x['etiket'] == 1)
            t = n_cn + n_emci
            print(f"  {set_adi}: CN={n_cn} ({100*n_cn/t:.1f}%) | EMCI={n_emci} ({100*n_emci/t:.1f}%)")
        print(f"{'='*70}")

        # Class weights (train dagilimina gore)
        if config['use_class_weights']:
            n_cn_tr   = sum(1 for x in tr_seans if x['etiket'] == 0)
            n_emci_tr = sum(1 for x in tr_seans if x['etiket'] == 1)
            n_total   = n_cn_tr + n_emci_tr
            w_cn   = n_total / (2 * n_cn_tr)
            w_emci = n_total / (2 * n_emci_tr)
            class_weights = torch.tensor([w_cn, w_emci], dtype=torch.float).to(DEVICE)
            print(f"Class Weights: CN={w_cn:.3f}, EMCI={w_emci:.3f}")
        else:
            class_weights = None

        # DataLoader'lar (SADECE train + val)
        train_loader = loader_olustur(tr_seans,  duzlem, config, shuffle=True)
        val_loader   = loader_olustur(val_seans, duzlem, config, shuffle=False)

        # Model
        model = model_olustur(
            dropout_rate=config['dropout'],
            hidden_dim=256,
            duzlem_adi=duzlem.upper()
        )

        # Optimizer (backbone + head ayri LR)
        backbone_params, head_params = [], []
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            if 'backbone' in name:
                backbone_params.append(param)
            else:
                head_params.append(param)

        optimizer = optim.AdamW([
            {'params': backbone_params, 'lr': config['lr_finetune'],
             'weight_decay': config['weight_decay']},
            {'params': head_params,     'lr': config['lr_head'],
             'weight_decay': config['weight_decay']}
        ])

        scheduler = optim.lr_scheduler.CosineAnnealingLR(
            optimizer, T_max=config['epoch'], eta_min=config['min_lr']
        )

        crit = nn.CrossEntropyLoss(
            weight=class_weights,
            label_smoothing=config['label_smoothing']
        )

        m_path = os.path.join(kayit_klasoru, f'{duzlem}_fold_{fold}.pth')
        es = EarlyStopping(patience=config['patience'], path=m_path)

        history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

        for epoch in range(1, config['epoch'] + 1):
            model.train()
            tr_loss, tr_correct, tr_total = 0.0, 0, 0

            for _, slices, lbls in train_loader:
                slices = slices.to(DEVICE)
                lbls   = lbls.to(DEVICE)
                optimizer.zero_grad()
                logits = model(slices)
                loss   = crit(logits, lbls)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(
                    model.parameters(), max_norm=config['grad_clip_norm']
                )
                optimizer.step()

                tr_loss    += loss.item()
                tr_correct += (logits.argmax(1) == lbls).sum().item()
                tr_total   += lbls.size(0)

            train_loss = tr_loss / len(train_loader)
            train_acc  = tr_correct / tr_total

            y_v_t, y_v_p, val_loss, _ = degerlendir(model, val_loader, kayip_fn=crit)
            val_acc = accuracy_score(y_v_t, y_v_p)
            val_macro_f1 = f1_score(y_v_t, y_v_p, average='macro', zero_division=0)

            history['train_loss'].append(train_loss)
            history['train_acc'].append(train_acc)
            history['val_loss'].append(val_loss)
            history['val_acc'].append(val_acc)

            improved = es(val_macro_f1, val_loss, val_acc, model)
            mark = "*" if improved else " "
            lr_bb = optimizer.param_groups[0]['lr']
            print(f"  Epoch {epoch:02d} {mark} | "
                  f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
                  f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f} | "
                  f"Val mF1: {val_macro_f1:.4f} | "
                  f"LR_bb: {lr_bb:.2e}")

            if epoch in [1, 5, 10, 15]:
                n_cn_v = sum(1 for p in y_v_p if p == 0)
                n_em_v = sum(1 for p in y_v_p if p == 1)
                print(f"         Val tahmin: CN={n_cn_v}, EMCI={n_em_v}")

            if es.early_stop:
                print(f"  Sabir tukendi, Fold {fold} durduruldu (epoch {epoch}).")
                break
            scheduler.step()

        # Grafik (KORUNDU)
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))
        ep_range = range(1, len(history['train_loss']) + 1)
        axes[0].plot(ep_range, history['train_loss'], 'b-', label='Train Loss', lw=2)
        axes[0].plot(ep_range, history['val_loss'],   'r-', label='Val Loss',   lw=2)
        axes[0].set_title(f'Fold {fold} [{duzlem.upper()}] Loss')
        axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Loss')
        axes[0].legend(); axes[0].grid(True, alpha=0.3)

        axes[1].plot(ep_range, history['train_acc'], 'b-', label='Train Acc', lw=2)
        axes[1].plot(ep_range, history['val_acc'],   'r-', label='Val Acc',   lw=2)
        axes[1].set_title(f'Fold {fold} [{duzlem.upper()}] Accuracy')
        axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Accuracy')
        axes[1].legend(); axes[1].grid(True, alpha=0.3); axes[1].set_ylim([0,1])

        plt.tight_layout()
        plt.savefig(os.path.join(kayit_klasoru, f'fold_{fold}_grafik.png'),
                    dpi=100, bbox_inches='tight')
        plt.show()

        pd.DataFrame(history).to_csv(
            os.path.join(kayit_klasoru, f'fold_{fold}_metrik.csv'), index=False
        )

        # === En iyi modeli yukle ve VALIDATION uzerinde degerlendir ===
        # (Confusion matrix fold icinde KALDIRILDI; sadece metrikler)
        model.load_state_dict(torch.load(m_path, weights_only=True))
        y_t, y_p, _, _ = degerlendir(model, val_loader)

        p, r, f, _ = precision_recall_fscore_support(y_t, y_p, average='weighted', zero_division=0)
        val_acc_best = accuracy_score(y_t, y_p)
        p_pc, r_pc, f_pc, _ = precision_recall_fscore_support(
            y_t, y_p, average=None, labels=[0, 1], zero_division=0
        )

        print(f"\nFOLD {fold} VALIDATION SONUCLARI [{duzlem.upper()}]")
        print(f"  Val Accuracy  : {val_acc_best:.4f}")
        print(f"  Precision     : {p:.4f}")
        print(f"  Recall        : {r:.4f}")
        print(f"  F1 Score      : {f:.4f}")
        print(f"  Per-Class F1  : CN={f_pc[0]:.4f} | EMCI={f_pc[1]:.4f} | "
              f"Fark={abs(f_pc[0]-f_pc[1]):.4f} "
              f"{'KONTROL ET' if abs(f_pc[0]-f_pc[1]) > 0.10 else 'Normal'}")
        print(f"  Best Val Loss : {es.best_loss:.4f}")
        print(f"  Model kaydi   : {m_path}")

        fold_skoru = {
            'fold': fold,
            'val_acc'  : val_acc_best,
            'val_prec' : p, 'val_rec': r, 'val_f1': f,
            'val_f1_cn': f_pc[0], 'val_f1_emci': f_pc[1],
            'best_val_loss': es.best_loss,
            'duzlem'       : duzlem,
            'durduran_epoch': len(history['train_loss'])
        }
        fold_results.append(fold_skoru)
        pd.DataFrame(fold_results).to_csv(csv_yolu, index=False)

        del model
        torch.cuda.empty_cache()

    return fold_results

print("Egitim fonksiyonu hazir (SADECE train/val; test izole).")
# Out:
# Egitim fonksiyonu hazir (SADECE train/val; test izole).

# %%
import time

sagital_klasoru = os.path.join(ANA_KLASOR, "Sagital")

print(f"EGITIM 1/3: SAGITAL")
print(f"Klasor: {sagital_klasoru}\n")

t0 = time.time()
sonuclar_sagital = duzlem_egit(tum_veriler, 'sagital', CONFIG, sagital_klasoru)
sure_sagital = time.time() - t0

df_sagital = pd.read_csv(os.path.join(sagital_klasoru, 'deney_sonuclari.csv'))
print(f"\nSAGITAL 5-FOLD VALIDATION SONUCLARI:")
print(df_sagital[['fold', 'val_acc', 'val_f1', 'best_val_loss']].to_string(index=False))
print(f"Ortalama Val Acc: {df_sagital['val_acc'].mean():.4f} +/- {df_sagital['val_acc'].std():.4f}")
print(f"Sure: {sure_sagital/60:.1f} dakika")
# Out:
# EGITIM 1/3: SAGITAL
# Klasor: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital
#
#
# ======================================================================
# DUZLEM: SAGITAL
# Klasor: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital
# ======================================================================
#
# ======================================================================
# FOLD 1 [SAGITAL]
#   Train: 396 hasta / 1704 seans
#   Val  : 70 hasta / 286 seans
#   Train: CN=903 (53.0%) | EMCI=801 (47.0%)
#   Val: CN=140 (49.0%) | EMCI=146 (51.0%)
# ======================================================================
# Class Weights: CN=0.944, EMCI=1.064
# [SAGITAL] Toplam param   : 7,216,770
# [SAGITAL] Egitilen param : 2,423,042 (33.58%)
# [SAGITAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6391 | Train Acc: 0.6479 | Val Loss: 0.6192 | Val Acc: 0.6573 | Val mF1: 0.6328 | LR_bb: 2.00e-04
#          Val tahmin: CN=72, EMCI=214
#   Epoch 02   | Train Loss: 0.4537 | Train Acc: 0.8374 | Val Loss: 0.7772 | Val Acc: 0.5874 | Val mF1: 0.5421 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3189 | Train Acc: 0.9419 | Val Loss: 0.8770 | Val Acc: 0.6434 | Val mF1: 0.6312 | LR_bb: 2.00e-04
#   Epoch 04 * | Train Loss: 0.2853 | Train Acc: 0.9642 | Val Loss: 0.7665 | Val Acc: 0.7133 | Val mF1: 0.7063 | LR_bb: 1.99e-04
#   Epoch 05 * | Train Loss: 0.2543 | Train Acc: 0.9836 | Val Loss: 0.6507 | Val Acc: 0.7378 | Val mF1: 0.7363 | LR_bb: 1.99e-04
#          Val tahmin: CN=125, EMCI=161
#   Epoch 06   | Train Loss: 0.2490 | Train Acc: 0.9900 | Val Loss: 0.6644 | Val Acc: 0.7203 | Val mF1: 0.7163 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2375 | Train Acc: 0.9941 | Val Loss: 0.6534 | Val Acc: 0.7063 | Val mF1: 0.7058 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2431 | Train Acc: 0.9930 | Val Loss: 0.9427 | Val Acc: 0.5629 | Val mF1: 0.5227 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2338 | Train Acc: 0.9994 | Val Loss: 0.8238 | Val Acc: 0.6014 | Val mF1: 0.5775 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2358 | Train Acc: 0.9935 | Val Loss: 0.8172 | Val Acc: 0.6329 | Val mF1: 0.6115 | LR_bb: 1.94e-04
#          Val tahmin: CN=213, EMCI=73
#   Epoch 11   | Train Loss: 0.2283 | Train Acc: 0.9988 | Val Loss: 0.6673 | Val Acc: 0.6853 | Val mF1: 0.6852 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2279 | Train Acc: 1.0000 | Val Loss: 0.6913 | Val Acc: 0.7203 | Val mF1: 0.7153 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2372 | Train Acc: 0.9930 | Val Loss: 0.6484 | Val Acc: 0.7028 | Val mF1: 0.7020 | LR_bb: 1.89e-04
#   Epoch 14   | Train Loss: 0.2313 | Train Acc: 0.9988 | Val Loss: 0.6330 | Val Acc: 0.7308 | Val mF1: 0.7307 | LR_bb: 1.87e-04
#   Epoch 15   | Train Loss: 0.2291 | Train Acc: 0.9965 | Val Loss: 0.6841 | Val Acc: 0.6783 | Val mF1: 0.6775 | LR_bb: 1.85e-04
#          Val tahmin: CN=132, EMCI=154
#   Epoch 16   | Train Loss: 0.2359 | Train Acc: 0.9935 | Val Loss: 0.6961 | Val Acc: 0.6923 | Val mF1: 0.6911 | LR_bb: 1.83e-04
#   Epoch 17   | Train Loss: 0.2290 | Train Acc: 0.9977 | Val Loss: 0.6536 | Val Acc: 0.7063 | Val mF1: 0.7062 | LR_bb: 1.81e-04
#   Sabir tukendi, Fold 1 durduruldu (epoch 17).
# FOLD 1 VALIDATION SONUCLARI [SAGITAL]
#   Val Accuracy  : 0.7378
#   Precision     : 0.7398
#   Recall        : 0.7378
#   F1 Score      : 0.7367
#   Per-Class F1  : CN=0.7170 | EMCI=0.7557 | Fark=0.0387 Normal
#   Best Val Loss : 0.6507
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_1.pth
#
# ======================================================================
# FOLD 2 [SAGITAL]
#   Train: 396 hasta / 1712 seans
#   Val  : 70 hasta / 278 seans
#   Train: CN=881 (51.5%) | EMCI=831 (48.5%)
#   Val: CN=162 (58.3%) | EMCI=116 (41.7%)
# ======================================================================
# Class Weights: CN=0.972, EMCI=1.030
# [SAGITAL] Toplam param   : 7,216,770
# [SAGITAL] Egitilen param : 2,423,042 (33.58%)
# [SAGITAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6506 | Train Acc: 0.6560 | Val Loss: 0.7236 | Val Acc: 0.5971 | Val mF1: 0.5788 | LR_bb: 2.00e-04
#          Val tahmin: CN=58, EMCI=220
#   Epoch 02   | Train Loss: 0.4390 | Train Acc: 0.8516 | Val Loss: 0.9087 | Val Acc: 0.5755 | Val mF1: 0.5636 | LR_bb: 2.00e-04
#   Epoch 03 * | Train Loss: 0.3351 | Train Acc: 0.9369 | Val Loss: 0.7436 | Val Acc: 0.6223 | Val mF1: 0.6223 | LR_bb: 2.00e-04
#   Epoch 04 * | Train Loss: 0.2594 | Train Acc: 0.9790 | Val Loss: 0.7812 | Val Acc: 0.6367 | Val mF1: 0.6342 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2588 | Train Acc: 0.9807 | Val Loss: 0.7207 | Val Acc: 0.6547 | Val mF1: 0.6313 | LR_bb: 1.99e-04
#          Val tahmin: CN=186, EMCI=92
#   Epoch 06 * | Train Loss: 0.2460 | Train Acc: 0.9901 | Val Loss: 0.7149 | Val Acc: 0.6835 | Val mF1: 0.6645 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2402 | Train Acc: 0.9930 | Val Loss: 0.9420 | Val Acc: 0.5935 | Val mF1: 0.5826 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2400 | Train Acc: 0.9907 | Val Loss: 0.7509 | Val Acc: 0.6619 | Val mF1: 0.6561 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2346 | Train Acc: 0.9947 | Val Loss: 0.8495 | Val Acc: 0.5971 | Val mF1: 0.5964 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2348 | Train Acc: 0.9936 | Val Loss: 0.7262 | Val Acc: 0.6403 | Val mF1: 0.6310 | LR_bb: 1.94e-04
#          Val tahmin: CN=160, EMCI=118
#   Epoch 11   | Train Loss: 0.2272 | Train Acc: 0.9977 | Val Loss: 1.0143 | Val Acc: 0.5935 | Val mF1: 0.5845 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2327 | Train Acc: 0.9942 | Val Loss: 1.0674 | Val Acc: 0.5719 | Val mF1: 0.5615 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2289 | Train Acc: 0.9959 | Val Loss: 0.8075 | Val Acc: 0.6511 | Val mF1: 0.6510 | LR_bb: 1.89e-04
#   Epoch 14 * | Train Loss: 0.2232 | Train Acc: 0.9982 | Val Loss: 0.7363 | Val Acc: 0.6691 | Val mF1: 0.6670 | LR_bb: 1.87e-04
#   Epoch 15   | Train Loss: 0.2268 | Train Acc: 0.9977 | Val Loss: 0.7441 | Val Acc: 0.6583 | Val mF1: 0.6583 | LR_bb: 1.85e-04
#          Val tahmin: CN=117, EMCI=161
#   Epoch 16   | Train Loss: 0.2270 | Train Acc: 0.9982 | Val Loss: 0.8308 | Val Acc: 0.6259 | Val mF1: 0.6252 | LR_bb: 1.83e-04
#   Epoch 17   | Train Loss: 0.2220 | Train Acc: 0.9982 | Val Loss: 0.8178 | Val Acc: 0.6331 | Val mF1: 0.6331 | LR_bb: 1.81e-04
#   Epoch 18   | Train Loss: 0.2236 | Train Acc: 0.9994 | Val Loss: 0.8927 | Val Acc: 0.6439 | Val mF1: 0.6428 | LR_bb: 1.79e-04
#   Epoch 19   | Train Loss: 0.2280 | Train Acc: 0.9947 | Val Loss: 0.8110 | Val Acc: 0.6295 | Val mF1: 0.6295 | LR_bb: 1.76e-04
#   Epoch 20   | Train Loss: 0.2239 | Train Acc: 0.9977 | Val Loss: 0.7644 | Val Acc: 0.6295 | Val mF1: 0.5705 | LR_bb: 1.74e-04
#   Epoch 21   | Train Loss: 0.2242 | Train Acc: 0.9977 | Val Loss: 0.7931 | Val Acc: 0.6187 | Val mF1: 0.6185 | LR_bb: 1.71e-04
#   Epoch 22   | Train Loss: 0.2223 | Train Acc: 0.9988 | Val Loss: 0.7661 | Val Acc: 0.6475 | Val mF1: 0.6456 | LR_bb: 1.68e-04
#   Epoch 23   | Train Loss: 0.2209 | Train Acc: 0.9994 | Val Loss: 0.8382 | Val Acc: 0.6151 | Val mF1: 0.6149 | LR_bb: 1.65e-04
#   Epoch 24   | Train Loss: 0.2201 | Train Acc: 0.9977 | Val Loss: 0.8327 | Val Acc: 0.6295 | Val mF1: 0.6278 | LR_bb: 1.62e-04
#   Epoch 25   | Train Loss: 0.2207 | Train Acc: 0.9994 | Val Loss: 0.7823 | Val Acc: 0.6727 | Val mF1: 0.6622 | LR_bb: 1.59e-04
#   Epoch 26   | Train Loss: 0.2236 | Train Acc: 0.9947 | Val Loss: 0.7727 | Val Acc: 0.6583 | Val mF1: 0.6454 | LR_bb: 1.56e-04
#   Sabir tukendi, Fold 2 durduruldu (epoch 26).
# FOLD 2 VALIDATION SONUCLARI [SAGITAL]
#   Val Accuracy  : 0.6691
#   Precision     : 0.6836
#   Recall        : 0.6691
#   F1 Score      : 0.6713
#   Per-Class F1  : CN=0.6933 | EMCI=0.6406 | Fark=0.0527 Normal
#   Best Val Loss : 0.7363
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_2.pth
#
# ======================================================================
# FOLD 3 [SAGITAL]
#   Train: 396 hasta / 1676 seans
#   Val  : 70 hasta / 314 seans
#   Train: CN=868 (51.8%) | EMCI=808 (48.2%)
#   Val: CN=175 (55.7%) | EMCI=139 (44.3%)
# ======================================================================
# Class Weights: CN=0.965, EMCI=1.037
# [SAGITAL] Toplam param   : 7,216,770
# [SAGITAL] Egitilen param : 2,423,042 (33.58%)
# [SAGITAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6266 | Train Acc: 0.6468 | Val Loss: 0.6554 | Val Acc: 0.6497 | Val mF1: 0.6450 | LR_bb: 2.00e-04
#          Val tahmin: CN=175, EMCI=139
#   Epoch 02 * | Train Loss: 0.4640 | Train Acc: 0.8371 | Val Loss: 0.6617 | Val Acc: 0.6911 | Val mF1: 0.6713 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3448 | Train Acc: 0.9206 | Val Loss: 0.9482 | Val Acc: 0.6178 | Val mF1: 0.5687 | LR_bb: 2.00e-04
#   Epoch 04 * | Train Loss: 0.2797 | Train Acc: 0.9660 | Val Loss: 0.7775 | Val Acc: 0.6752 | Val mF1: 0.6722 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2455 | Train Acc: 0.9881 | Val Loss: 1.0813 | Val Acc: 0.6178 | Val mF1: 0.5499 | LR_bb: 1.99e-04
#          Val tahmin: CN=261, EMCI=53
#   Epoch 06   | Train Loss: 0.2394 | Train Acc: 0.9911 | Val Loss: 0.8415 | Val Acc: 0.6688 | Val mF1: 0.6262 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2359 | Train Acc: 0.9928 | Val Loss: 0.7860 | Val Acc: 0.6529 | Val mF1: 0.6342 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2419 | Train Acc: 0.9928 | Val Loss: 0.8554 | Val Acc: 0.6720 | Val mF1: 0.6251 | LR_bb: 1.96e-04
#   Epoch 09 * | Train Loss: 0.2349 | Train Acc: 0.9958 | Val Loss: 0.7186 | Val Acc: 0.6943 | Val mF1: 0.6887 | LR_bb: 1.95e-04
#   Epoch 10 * | Train Loss: 0.2320 | Train Acc: 0.9964 | Val Loss: 0.7196 | Val Acc: 0.7038 | Val mF1: 0.7016 | LR_bb: 1.94e-04
#          Val tahmin: CN=166, EMCI=148
#   Epoch 11   | Train Loss: 0.2303 | Train Acc: 0.9976 | Val Loss: 0.7766 | Val Acc: 0.6879 | Val mF1: 0.6878 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2317 | Train Acc: 0.9964 | Val Loss: 0.7526 | Val Acc: 0.6465 | Val mF1: 0.6410 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2254 | Train Acc: 0.9982 | Val Loss: 0.7632 | Val Acc: 0.6847 | Val mF1: 0.6787 | LR_bb: 1.89e-04
#   Epoch 14   | Train Loss: 0.2282 | Train Acc: 0.9988 | Val Loss: 0.7165 | Val Acc: 0.6783 | Val mF1: 0.6748 | LR_bb: 1.87e-04
#   Epoch 15   | Train Loss: 0.2220 | Train Acc: 1.0000 | Val Loss: 0.7431 | Val Acc: 0.6815 | Val mF1: 0.6790 | LR_bb: 1.85e-04
#          Val tahmin: CN=167, EMCI=147
#   Epoch 16   | Train Loss: 0.2280 | Train Acc: 0.9958 | Val Loss: 0.7431 | Val Acc: 0.6720 | Val mF1: 0.6638 | LR_bb: 1.83e-04
#   Epoch 17   | Train Loss: 0.2272 | Train Acc: 0.9952 | Val Loss: 0.7347 | Val Acc: 0.6815 | Val mF1: 0.6793 | LR_bb: 1.81e-04
#   Epoch 18   | Train Loss: 0.2229 | Train Acc: 0.9994 | Val Loss: 0.7197 | Val Acc: 0.6879 | Val mF1: 0.6874 | LR_bb: 1.79e-04
#   Epoch 19   | Train Loss: 0.2223 | Train Acc: 0.9988 | Val Loss: 0.7350 | Val Acc: 0.6688 | Val mF1: 0.6609 | LR_bb: 1.76e-04
#   Epoch 20   | Train Loss: 0.2216 | Train Acc: 0.9988 | Val Loss: 0.7734 | Val Acc: 0.6720 | Val mF1: 0.6573 | LR_bb: 1.74e-04
#   Epoch 21   | Train Loss: 0.2222 | Train Acc: 0.9982 | Val Loss: 0.7779 | Val Acc: 0.6720 | Val mF1: 0.6543 | LR_bb: 1.71e-04
#   Epoch 22 * | Train Loss: 0.2220 | Train Acc: 0.9982 | Val Loss: 0.7596 | Val Acc: 0.7038 | Val mF1: 0.7037 | LR_bb: 1.68e-04
#   Epoch 23   | Train Loss: 0.2190 | Train Acc: 0.9982 | Val Loss: 0.7255 | Val Acc: 0.7038 | Val mF1: 0.7027 | LR_bb: 1.65e-04
#   Epoch 24 * | Train Loss: 0.2179 | Train Acc: 1.0000 | Val Loss: 0.7348 | Val Acc: 0.7134 | Val mF1: 0.7111 | LR_bb: 1.62e-04
#   Epoch 25   | Train Loss: 0.2187 | Train Acc: 1.0000 | Val Loss: 0.7635 | Val Acc: 0.6879 | Val mF1: 0.6878 | LR_bb: 1.59e-04
#   Epoch 26   | Train Loss: 0.2172 | Train Acc: 1.0000 | Val Loss: 0.7289 | Val Acc: 0.6783 | Val mF1: 0.6696 | LR_bb: 1.56e-04
#   Epoch 27   | Train Loss: 0.2177 | Train Acc: 0.9994 | Val Loss: 0.7296 | Val Acc: 0.6783 | Val mF1: 0.6772 | LR_bb: 1.52e-04
#   Epoch 28   | Train Loss: 0.2213 | Train Acc: 0.9976 | Val Loss: 0.7185 | Val Acc: 0.6847 | Val mF1: 0.6838 | LR_bb: 1.49e-04
#   Epoch 29   | Train Loss: 0.2181 | Train Acc: 1.0000 | Val Loss: 0.7299 | Val Acc: 0.6783 | Val mF1: 0.6689 | LR_bb: 1.46e-04
#   Epoch 30 * | Train Loss: 0.2180 | Train Acc: 0.9994 | Val Loss: 0.6890 | Val Acc: 0.7197 | Val mF1: 0.7195 | LR_bb: 1.42e-04
#   Epoch 31   | Train Loss: 0.2189 | Train Acc: 0.9988 | Val Loss: 0.7755 | Val Acc: 0.7102 | Val mF1: 0.7065 | LR_bb: 1.39e-04
#   Epoch 32   | Train Loss: 0.2178 | Train Acc: 1.0000 | Val Loss: 0.7382 | Val Acc: 0.6688 | Val mF1: 0.6633 | LR_bb: 1.35e-04
#   Epoch 33   | Train Loss: 0.2176 | Train Acc: 0.9988 | Val Loss: 0.7686 | Val Acc: 0.6847 | Val mF1: 0.6847 | LR_bb: 1.31e-04
#   Epoch 34   | Train Loss: 0.2167 | Train Acc: 0.9994 | Val Loss: 0.7449 | Val Acc: 0.6720 | Val mF1: 0.6591 | LR_bb: 1.28e-04
#   Epoch 35   | Train Loss: 0.2170 | Train Acc: 1.0000 | Val Loss: 0.7276 | Val Acc: 0.6688 | Val mF1: 0.6587 | LR_bb: 1.24e-04
#   Epoch 36   | Train Loss: 0.2146 | Train Acc: 1.0000 | Val Loss: 0.7415 | Val Acc: 0.6847 | Val mF1: 0.6842 | LR_bb: 1.20e-04
#   Epoch 37   | Train Loss: 0.2165 | Train Acc: 1.0000 | Val Loss: 0.7439 | Val Acc: 0.6656 | Val mF1: 0.6635 | LR_bb: 1.16e-04
#   Epoch 38   | Train Loss: 0.2161 | Train Acc: 0.9994 | Val Loss: 0.8988 | Val Acc: 0.6592 | Val mF1: 0.6163 | LR_bb: 1.12e-04
#   Epoch 39   | Train Loss: 0.2155 | Train Acc: 1.0000 | Val Loss: 0.7593 | Val Acc: 0.6592 | Val mF1: 0.6591 | LR_bb: 1.08e-04
#   Epoch 40   | Train Loss: 0.2155 | Train Acc: 1.0000 | Val Loss: 0.7270 | Val Acc: 0.6815 | Val mF1: 0.6732 | LR_bb: 1.04e-04
#   Epoch 41   | Train Loss: 0.2159 | Train Acc: 1.0000 | Val Loss: 0.7346 | Val Acc: 0.6815 | Val mF1: 0.6800 | LR_bb: 1.01e-04
#   Epoch 42   | Train Loss: 0.2141 | Train Acc: 1.0000 | Val Loss: 0.7188 | Val Acc: 0.7070 | Val mF1: 0.7062 | LR_bb: 9.66e-05
#   Sabir tukendi, Fold 3 durduruldu (epoch 42).
# FOLD 3 VALIDATION SONUCLARI [SAGITAL]
#   Val Accuracy  : 0.7197
#   Precision     : 0.7311
#   Recall        : 0.7197
#   F1 Score      : 0.7205
#   Per-Class F1  : CN=0.7284 | EMCI=0.7105 | Fark=0.0179 Normal
#   Best Val Loss : 0.6890
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_3.pth
#
# ======================================================================
# FOLD 4 [SAGITAL]
#   Train: 396 hasta / 1701 seans
#   Val  : 70 hasta / 289 seans
#   Train: CN=888 (52.2%) | EMCI=813 (47.8%)
#   Val: CN=155 (53.6%) | EMCI=134 (46.4%)
# ======================================================================
# Class Weights: CN=0.958, EMCI=1.046
# [SAGITAL] Toplam param   : 7,216,770
# [SAGITAL] Egitilen param : 2,423,042 (33.58%)
# [SAGITAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6595 | Train Acc: 0.6179 | Val Loss: 0.6354 | Val Acc: 0.6920 | Val mF1: 0.6772 | LR_bb: 2.00e-04
#          Val tahmin: CN=72, EMCI=217
#   Epoch 02 * | Train Loss: 0.4515 | Train Acc: 0.8360 | Val Loss: 0.6866 | Val Acc: 0.7405 | Val mF1: 0.7304 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3320 | Train Acc: 0.9312 | Val Loss: 0.8680 | Val Acc: 0.6713 | Val mF1: 0.6642 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2836 | Train Acc: 0.9659 | Val Loss: 0.6736 | Val Acc: 0.7128 | Val mF1: 0.7108 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2595 | Train Acc: 0.9806 | Val Loss: 0.6514 | Val Acc: 0.7093 | Val mF1: 0.7081 | LR_bb: 1.99e-04
#          Val tahmin: CN=153, EMCI=136
#   Epoch 06   | Train Loss: 0.2434 | Train Acc: 0.9929 | Val Loss: 0.8952 | Val Acc: 0.6678 | Val mF1: 0.6588 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2441 | Train Acc: 0.9912 | Val Loss: 0.7139 | Val Acc: 0.7059 | Val mF1: 0.6989 | LR_bb: 1.97e-04
#   Epoch 08 * | Train Loss: 0.2354 | Train Acc: 0.9982 | Val Loss: 0.6465 | Val Acc: 0.7439 | Val mF1: 0.7439 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2392 | Train Acc: 0.9935 | Val Loss: 0.6861 | Val Acc: 0.7232 | Val mF1: 0.7211 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2452 | Train Acc: 0.9900 | Val Loss: 0.6758 | Val Acc: 0.7232 | Val mF1: 0.7191 | LR_bb: 1.94e-04
#          Val tahmin: CN=169, EMCI=120
#   Epoch 11   | Train Loss: 0.2386 | Train Acc: 0.9941 | Val Loss: 0.6782 | Val Acc: 0.7059 | Val mF1: 0.6960 | LR_bb: 1.92e-04
#   Epoch 12 * | Train Loss: 0.2329 | Train Acc: 0.9982 | Val Loss: 0.6259 | Val Acc: 0.7612 | Val mF1: 0.7603 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2307 | Train Acc: 0.9982 | Val Loss: 0.6486 | Val Acc: 0.7336 | Val mF1: 0.7334 | LR_bb: 1.89e-04
#   Epoch 14   | Train Loss: 0.2286 | Train Acc: 0.9982 | Val Loss: 0.6839 | Val Acc: 0.7232 | Val mF1: 0.7229 | LR_bb: 1.87e-04
#   Epoch 15   | Train Loss: 0.2282 | Train Acc: 0.9988 | Val Loss: 0.6799 | Val Acc: 0.7128 | Val mF1: 0.7128 | LR_bb: 1.85e-04
#          Val tahmin: CN=136, EMCI=153
#   Epoch 16   | Train Loss: 0.2325 | Train Acc: 0.9953 | Val Loss: 0.6327 | Val Acc: 0.7128 | Val mF1: 0.7114 | LR_bb: 1.83e-04
#   Epoch 17   | Train Loss: 0.2296 | Train Acc: 0.9971 | Val Loss: 0.6827 | Val Acc: 0.7059 | Val mF1: 0.7022 | LR_bb: 1.81e-04
#   Epoch 18   | Train Loss: 0.2276 | Train Acc: 0.9971 | Val Loss: 0.7927 | Val Acc: 0.6920 | Val mF1: 0.6740 | LR_bb: 1.79e-04
#   Epoch 19   | Train Loss: 0.2266 | Train Acc: 0.9988 | Val Loss: 0.6811 | Val Acc: 0.6782 | Val mF1: 0.6725 | LR_bb: 1.76e-04
#   Epoch 20   | Train Loss: 0.2265 | Train Acc: 0.9988 | Val Loss: 0.7844 | Val Acc: 0.7093 | Val mF1: 0.6948 | LR_bb: 1.74e-04
#   Epoch 21   | Train Loss: 0.2248 | Train Acc: 1.0000 | Val Loss: 0.6772 | Val Acc: 0.7024 | Val mF1: 0.7005 | LR_bb: 1.71e-04
#   Epoch 22   | Train Loss: 0.2235 | Train Acc: 0.9982 | Val Loss: 0.6985 | Val Acc: 0.7024 | Val mF1: 0.7020 | LR_bb: 1.68e-04
#   Epoch 23   | Train Loss: 0.2339 | Train Acc: 0.9965 | Val Loss: 0.6738 | Val Acc: 0.7093 | Val mF1: 0.7034 | LR_bb: 1.65e-04
#   Epoch 24   | Train Loss: 0.2232 | Train Acc: 1.0000 | Val Loss: 0.7422 | Val Acc: 0.6920 | Val mF1: 0.6918 | LR_bb: 1.62e-04
#   Sabir tukendi, Fold 4 durduruldu (epoch 24).
# FOLD 4 VALIDATION SONUCLARI [SAGITAL]
#   Val Accuracy  : 0.7612
#   Precision     : 0.7617
#   Recall        : 0.7612
#   F1 Score      : 0.7614
#   Per-Class F1  : CN=0.7752 | EMCI=0.7454 | Fark=0.0299 Normal
#   Best Val Loss : 0.6259
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_4.pth
#
# ======================================================================
# FOLD 5 [SAGITAL]
#   Train: 396 hasta / 1714 seans
#   Val  : 70 hasta / 276 seans
#   Train: CN=923 (53.9%) | EMCI=791 (46.1%)
#   Val: CN=120 (43.5%) | EMCI=156 (56.5%)
# ======================================================================
# Class Weights: CN=0.928, EMCI=1.083
# [SAGITAL] Toplam param   : 7,216,770
# [SAGITAL] Egitilen param : 2,423,042 (33.58%)
# [SAGITAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6097 | Train Acc: 0.6873 | Val Loss: 0.6376 | Val Acc: 0.6667 | Val mF1: 0.6289 | LR_bb: 2.00e-04
#          Val tahmin: CN=68, EMCI=208
#   Epoch 02   | Train Loss: 0.4364 | Train Acc: 0.8600 | Val Loss: 0.8257 | Val Acc: 0.5688 | Val mF1: 0.5548 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3274 | Train Acc: 0.9417 | Val Loss: 0.9589 | Val Acc: 0.5797 | Val mF1: 0.5759 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2710 | Train Acc: 0.9772 | Val Loss: 0.8912 | Val Acc: 0.6014 | Val mF1: 0.5879 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2556 | Train Acc: 0.9860 | Val Loss: 0.9315 | Val Acc: 0.5797 | Val mF1: 0.5765 | LR_bb: 1.99e-04
#          Val tahmin: CN=180, EMCI=96
#   Epoch 06   | Train Loss: 0.2432 | Train Acc: 0.9912 | Val Loss: 0.9296 | Val Acc: 0.6087 | Val mF1: 0.6087 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2413 | Train Acc: 0.9959 | Val Loss: 0.8659 | Val Acc: 0.6558 | Val mF1: 0.6284 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2354 | Train Acc: 0.9936 | Val Loss: 0.8685 | Val Acc: 0.6268 | Val mF1: 0.6102 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2391 | Train Acc: 0.9936 | Val Loss: 0.9026 | Val Acc: 0.5978 | Val mF1: 0.5966 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2305 | Train Acc: 0.9977 | Val Loss: 0.8090 | Val Acc: 0.6377 | Val mF1: 0.6282 | LR_bb: 1.94e-04
#          Val tahmin: CN=112, EMCI=164
#   Epoch 11   | Train Loss: 0.2279 | Train Acc: 0.9994 | Val Loss: 0.8187 | Val Acc: 0.6087 | Val mF1: 0.6062 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2395 | Train Acc: 0.9971 | Val Loss: 0.8522 | Val Acc: 0.6159 | Val mF1: 0.6107 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2351 | Train Acc: 0.9953 | Val Loss: 0.8063 | Val Acc: 0.6268 | Val mF1: 0.6166 | LR_bb: 1.89e-04
#   Sabir tukendi, Fold 5 durduruldu (epoch 13).
# FOLD 5 VALIDATION SONUCLARI [SAGITAL]
#   Val Accuracy  : 0.6667
#   Precision     : 0.6765
#   Recall        : 0.6667
#   F1 Score      : 0.6444
#   Per-Class F1  : CN=0.5106 | EMCI=0.7473 | Fark=0.2366 KONTROL ET
#   Best Val Loss : 0.6376
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_5.pth
#
# SAGITAL 5-FOLD VALIDATION SONUCLARI:
#  fold  val_acc   val_f1  best_val_loss
#     1 0.737762 0.736747       0.650737
#     2 0.669065 0.671340       0.736328
#     3 0.719745 0.720485       0.689030
#     4 0.761246 0.761401       0.625868
#     5 0.666667 0.644377       0.637572
# Ortalama Val Acc: 0.7109 +/- 0.0420
# Sure: 35.4 dakika

# %%
import time

aksiyal_klasoru = os.path.join(ANA_KLASOR, "Aksiyal")

print(f"EGITIM 2/3: AKSIYAL")
print(f"Klasor: {aksiyal_klasoru}\n")

t0 = time.time()
sonuclar_aksiyal = duzlem_egit(tum_veriler, 'aksiyal', CONFIG, aksiyal_klasoru)
sure_aksiyal = time.time() - t0

df_aksiyal = pd.read_csv(os.path.join(aksiyal_klasoru, 'deney_sonuclari.csv'))
print(f"\nAKSIYAL 5-FOLD VALIDATION SONUCLARI:")
print(df_aksiyal[['fold', 'val_acc', 'val_f1', 'best_val_loss']].to_string(index=False))
print(f"Ortalama Val Acc: {df_aksiyal['val_acc'].mean():.4f} +/- {df_aksiyal['val_acc'].std():.4f}")
print(f"Sure: {sure_aksiyal/60:.1f} dakika")
# Out:
# EGITIM 2/3: AKSIYAL
# Klasor: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal
#
#
# ======================================================================
# DUZLEM: AKSIYAL
# Klasor: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal
# ======================================================================
#
# ======================================================================
# FOLD 1 [AKSIYAL]
#   Train: 396 hasta / 1704 seans
#   Val  : 70 hasta / 286 seans
#   Train: CN=903 (53.0%) | EMCI=801 (47.0%)
#   Val: CN=140 (49.0%) | EMCI=146 (51.0%)
# ======================================================================
# Class Weights: CN=0.944, EMCI=1.064
# [AKSIYAL] Toplam param   : 7,216,770
# [AKSIYAL] Egitilen param : 2,423,042 (33.58%)
# [AKSIYAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6658 | Train Acc: 0.6121 | Val Loss: 0.6939 | Val Acc: 0.5420 | Val mF1: 0.4904 | LR_bb: 2.00e-04
#          Val tahmin: CN=237, EMCI=49
#   Epoch 02 * | Train Loss: 0.4819 | Train Acc: 0.8210 | Val Loss: 0.6371 | Val Acc: 0.6993 | Val mF1: 0.6968 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3379 | Train Acc: 0.9349 | Val Loss: 0.8741 | Val Acc: 0.6294 | Val mF1: 0.5962 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.3000 | Train Acc: 0.9572 | Val Loss: 0.8012 | Val Acc: 0.6294 | Val mF1: 0.6287 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2683 | Train Acc: 0.9806 | Val Loss: 0.8572 | Val Acc: 0.6189 | Val mF1: 0.6042 | LR_bb: 1.99e-04
#          Val tahmin: CN=201, EMCI=85
#   Epoch 06   | Train Loss: 0.2550 | Train Acc: 0.9900 | Val Loss: 0.7495 | Val Acc: 0.6469 | Val mF1: 0.6467 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2512 | Train Acc: 0.9900 | Val Loss: 0.7396 | Val Acc: 0.6643 | Val mF1: 0.6635 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2607 | Train Acc: 0.9888 | Val Loss: 0.7761 | Val Acc: 0.6294 | Val mF1: 0.6293 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2417 | Train Acc: 0.9959 | Val Loss: 0.7949 | Val Acc: 0.6364 | Val mF1: 0.6312 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2496 | Train Acc: 0.9941 | Val Loss: 0.8314 | Val Acc: 0.6189 | Val mF1: 0.6168 | LR_bb: 1.94e-04
#          Val tahmin: CN=167, EMCI=119
#   Epoch 11   | Train Loss: 0.2384 | Train Acc: 0.9953 | Val Loss: 0.7469 | Val Acc: 0.6608 | Val mF1: 0.6522 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2375 | Train Acc: 0.9953 | Val Loss: 0.7780 | Val Acc: 0.6294 | Val mF1: 0.6275 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2350 | Train Acc: 0.9994 | Val Loss: 0.7579 | Val Acc: 0.6538 | Val mF1: 0.6512 | LR_bb: 1.89e-04
#   Epoch 14   | Train Loss: 0.2363 | Train Acc: 0.9965 | Val Loss: 0.8778 | Val Acc: 0.6189 | Val mF1: 0.6007 | LR_bb: 1.87e-04
#   Sabir tukendi, Fold 1 durduruldu (epoch 14).
# FOLD 1 VALIDATION SONUCLARI [AKSIYAL]
#   Val Accuracy  : 0.6993
#   Precision     : 0.7112
#   Recall        : 0.6993
#   F1 Score      : 0.6962
#   Per-Class F1  : CN=0.7244 | EMCI=0.6692 | Fark=0.0551 Normal
#   Best Val Loss : 0.6371
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_1.pth
#
# ======================================================================
# FOLD 2 [AKSIYAL]
#   Train: 396 hasta / 1712 seans
#   Val  : 70 hasta / 278 seans
#   Train: CN=881 (51.5%) | EMCI=831 (48.5%)
#   Val: CN=162 (58.3%) | EMCI=116 (41.7%)
# ======================================================================
# Class Weights: CN=0.972, EMCI=1.030
# [AKSIYAL] Toplam param   : 7,216,770
# [AKSIYAL] Egitilen param : 2,423,042 (33.58%)
# [AKSIYAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6663 | Train Acc: 0.6086 | Val Loss: 0.6376 | Val Acc: 0.6187 | Val mF1: 0.6167 | LR_bb: 2.00e-04
#          Val tahmin: CN=96, EMCI=182
#   Epoch 02   | Train Loss: 0.4904 | Train Acc: 0.8096 | Val Loss: 0.6922 | Val Acc: 0.6007 | Val mF1: 0.5984 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3375 | Train Acc: 0.9334 | Val Loss: 0.7628 | Val Acc: 0.6331 | Val mF1: 0.5962 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2852 | Train Acc: 0.9673 | Val Loss: 0.9040 | Val Acc: 0.5468 | Val mF1: 0.5102 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2682 | Train Acc: 0.9848 | Val Loss: 0.8888 | Val Acc: 0.5863 | Val mF1: 0.5762 | LR_bb: 1.99e-04
#          Val tahmin: CN=159, EMCI=119
#   Epoch 06   | Train Loss: 0.2522 | Train Acc: 0.9877 | Val Loss: 0.8082 | Val Acc: 0.5827 | Val mF1: 0.5451 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2495 | Train Acc: 0.9918 | Val Loss: 0.8458 | Val Acc: 0.6007 | Val mF1: 0.6007 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2457 | Train Acc: 0.9907 | Val Loss: 0.8834 | Val Acc: 0.6043 | Val mF1: 0.6013 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2443 | Train Acc: 0.9936 | Val Loss: 0.8267 | Val Acc: 0.6007 | Val mF1: 0.6007 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2364 | Train Acc: 0.9988 | Val Loss: 0.8683 | Val Acc: 0.5683 | Val mF1: 0.5071 | LR_bb: 1.94e-04
#          Val tahmin: CN=214, EMCI=64
#   Epoch 11   | Train Loss: 0.2363 | Train Acc: 0.9982 | Val Loss: 0.9096 | Val Acc: 0.5719 | Val mF1: 0.5255 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2416 | Train Acc: 0.9930 | Val Loss: 0.8021 | Val Acc: 0.5647 | Val mF1: 0.5483 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2347 | Train Acc: 0.9965 | Val Loss: 0.8384 | Val Acc: 0.5683 | Val mF1: 0.5071 | LR_bb: 1.89e-04
#   Sabir tukendi, Fold 2 durduruldu (epoch 13).
# FOLD 2 VALIDATION SONUCLARI [AKSIYAL]
#   Val Accuracy  : 0.6187
#   Precision     : 0.6814
#   Recall        : 0.6187
#   F1 Score      : 0.6122
#   Per-Class F1  : CN=0.5891 | EMCI=0.6443 | Fark=0.0551 Normal
#   Best Val Loss : 0.6376
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_2.pth
#
# ======================================================================
# FOLD 3 [AKSIYAL]
#   Train: 396 hasta / 1676 seans
#   Val  : 70 hasta / 314 seans
#   Train: CN=868 (51.8%) | EMCI=808 (48.2%)
#   Val: CN=175 (55.7%) | EMCI=139 (44.3%)
# ======================================================================
# Class Weights: CN=0.965, EMCI=1.037
# [AKSIYAL] Toplam param   : 7,216,770
# [AKSIYAL] Egitilen param : 2,423,042 (33.58%)
# [AKSIYAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6636 | Train Acc: 0.6295 | Val Loss: 0.5841 | Val Acc: 0.6752 | Val mF1: 0.6726 | LR_bb: 2.00e-04
#          Val tahmin: CN=167, EMCI=147
#   Epoch 02   | Train Loss: 0.4746 | Train Acc: 0.8073 | Val Loss: 0.6780 | Val Acc: 0.6465 | Val mF1: 0.6361 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3381 | Train Acc: 0.9212 | Val Loss: 0.7513 | Val Acc: 0.6401 | Val mF1: 0.6370 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2893 | Train Acc: 0.9654 | Val Loss: 0.7760 | Val Acc: 0.6561 | Val mF1: 0.6554 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2465 | Train Acc: 0.9899 | Val Loss: 0.7955 | Val Acc: 0.6115 | Val mF1: 0.6074 | LR_bb: 1.99e-04
#          Val tahmin: CN=171, EMCI=143
#   Epoch 06   | Train Loss: 0.2472 | Train Acc: 0.9869 | Val Loss: 0.7661 | Val Acc: 0.6688 | Val mF1: 0.6535 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2301 | Train Acc: 0.9970 | Val Loss: 0.7903 | Val Acc: 0.6561 | Val mF1: 0.6504 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2319 | Train Acc: 0.9976 | Val Loss: 0.9004 | Val Acc: 0.6178 | Val mF1: 0.6163 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2271 | Train Acc: 0.9970 | Val Loss: 0.8032 | Val Acc: 0.6210 | Val mF1: 0.6208 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2249 | Train Acc: 0.9982 | Val Loss: 0.8411 | Val Acc: 0.6592 | Val mF1: 0.6430 | LR_bb: 1.94e-04
#          Val tahmin: CN=206, EMCI=108
#   Epoch 11   | Train Loss: 0.2290 | Train Acc: 0.9988 | Val Loss: 0.8046 | Val Acc: 0.6465 | Val mF1: 0.6171 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2274 | Train Acc: 0.9982 | Val Loss: 0.8423 | Val Acc: 0.6592 | Val mF1: 0.6233 | LR_bb: 1.91e-04
#   Epoch 13 * | Train Loss: 0.2252 | Train Acc: 0.9982 | Val Loss: 0.7606 | Val Acc: 0.6815 | Val mF1: 0.6815 | LR_bb: 1.89e-04
#   Epoch 14   | Train Loss: 0.2242 | Train Acc: 0.9988 | Val Loss: 0.8562 | Val Acc: 0.6338 | Val mF1: 0.6204 | LR_bb: 1.87e-04
#   Epoch 15   | Train Loss: 0.2259 | Train Acc: 0.9982 | Val Loss: 0.7814 | Val Acc: 0.6401 | Val mF1: 0.6401 | LR_bb: 1.85e-04
#          Val tahmin: CN=138, EMCI=176
#   Epoch 16   | Train Loss: 0.2229 | Train Acc: 0.9994 | Val Loss: 0.7907 | Val Acc: 0.6306 | Val mF1: 0.6298 | LR_bb: 1.83e-04
#   Epoch 17   | Train Loss: 0.2268 | Train Acc: 0.9982 | Val Loss: 0.8534 | Val Acc: 0.6656 | Val mF1: 0.6648 | LR_bb: 1.81e-04
#   Epoch 18   | Train Loss: 0.2220 | Train Acc: 1.0000 | Val Loss: 0.8254 | Val Acc: 0.6401 | Val mF1: 0.6366 | LR_bb: 1.79e-04
#   Epoch 19   | Train Loss: 0.2224 | Train Acc: 0.9982 | Val Loss: 0.7550 | Val Acc: 0.6529 | Val mF1: 0.6442 | LR_bb: 1.76e-04
#   Epoch 20   | Train Loss: 0.2247 | Train Acc: 0.9982 | Val Loss: 0.8045 | Val Acc: 0.6561 | Val mF1: 0.6456 | LR_bb: 1.74e-04
#   Epoch 21   | Train Loss: 0.2261 | Train Acc: 0.9964 | Val Loss: 0.8608 | Val Acc: 0.6306 | Val mF1: 0.6298 | LR_bb: 1.71e-04
#   Epoch 22   | Train Loss: 0.2219 | Train Acc: 0.9994 | Val Loss: 0.7283 | Val Acc: 0.6592 | Val mF1: 0.6533 | LR_bb: 1.68e-04
#   Epoch 23   | Train Loss: 0.2209 | Train Acc: 0.9994 | Val Loss: 0.7775 | Val Acc: 0.6529 | Val mF1: 0.6485 | LR_bb: 1.65e-04
#   Epoch 24   | Train Loss: 0.2214 | Train Acc: 0.9994 | Val Loss: 0.7922 | Val Acc: 0.6529 | Val mF1: 0.6419 | LR_bb: 1.62e-04
#   Epoch 25   | Train Loss: 0.2215 | Train Acc: 0.9988 | Val Loss: 0.7905 | Val Acc: 0.6783 | Val mF1: 0.6620 | LR_bb: 1.59e-04
#   Sabir tukendi, Fold 3 durduruldu (epoch 25).
# FOLD 3 VALIDATION SONUCLARI [AKSIYAL]
#   Val Accuracy  : 0.6815
#   Precision     : 0.7030
#   Recall        : 0.6815
#   F1 Score      : 0.6810
#   Per-Class F1  : CN=0.6774 | EMCI=0.6855 | Fark=0.0081 Normal
#   Best Val Loss : 0.7606
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_3.pth
#
# ======================================================================
# FOLD 4 [AKSIYAL]
#   Train: 396 hasta / 1701 seans
#   Val  : 70 hasta / 289 seans
#   Train: CN=888 (52.2%) | EMCI=813 (47.8%)
#   Val: CN=155 (53.6%) | EMCI=134 (46.4%)
# ======================================================================
# Class Weights: CN=0.958, EMCI=1.046
# [AKSIYAL] Toplam param   : 7,216,770
# [AKSIYAL] Egitilen param : 2,423,042 (33.58%)
# [AKSIYAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6674 | Train Acc: 0.6279 | Val Loss: 0.5901 | Val Acc: 0.6886 | Val mF1: 0.6854 | LR_bb: 2.00e-04
#          Val tahmin: CN=105, EMCI=184
#   Epoch 02   | Train Loss: 0.5172 | Train Acc: 0.7860 | Val Loss: 0.8355 | Val Acc: 0.5882 | Val mF1: 0.5882 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3738 | Train Acc: 0.9053 | Val Loss: 0.7488 | Val Acc: 0.6713 | Val mF1: 0.6710 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2979 | Train Acc: 0.9559 | Val Loss: 0.7489 | Val Acc: 0.6644 | Val mF1: 0.6636 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2641 | Train Acc: 0.9818 | Val Loss: 0.8924 | Val Acc: 0.6505 | Val mF1: 0.6231 | LR_bb: 1.99e-04
#          Val tahmin: CN=212, EMCI=77
#   Epoch 06   | Train Loss: 0.2442 | Train Acc: 0.9924 | Val Loss: 0.8431 | Val Acc: 0.6574 | Val mF1: 0.6398 | LR_bb: 1.98e-04
#   Epoch 07 * | Train Loss: 0.2463 | Train Acc: 0.9871 | Val Loss: 0.7613 | Val Acc: 0.6920 | Val mF1: 0.6919 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2479 | Train Acc: 0.9912 | Val Loss: 0.7592 | Val Acc: 0.6920 | Val mF1: 0.6918 | LR_bb: 1.96e-04
#   Epoch 09 * | Train Loss: 0.2440 | Train Acc: 0.9929 | Val Loss: 0.7337 | Val Acc: 0.7128 | Val mF1: 0.7114 | LR_bb: 1.95e-04
#   Epoch 10 * | Train Loss: 0.2378 | Train Acc: 0.9971 | Val Loss: 0.7356 | Val Acc: 0.7232 | Val mF1: 0.7220 | LR_bb: 1.94e-04
#          Val tahmin: CN=153, EMCI=136
#   Epoch 11   | Train Loss: 0.2345 | Train Acc: 0.9982 | Val Loss: 0.7981 | Val Acc: 0.6678 | Val mF1: 0.6465 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2416 | Train Acc: 0.9947 | Val Loss: 0.7808 | Val Acc: 0.6851 | Val mF1: 0.6802 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2449 | Train Acc: 0.9947 | Val Loss: 0.7154 | Val Acc: 0.7163 | Val mF1: 0.7160 | LR_bb: 1.89e-04
#   Epoch 14   | Train Loss: 0.2318 | Train Acc: 0.9988 | Val Loss: 0.7008 | Val Acc: 0.6747 | Val mF1: 0.6699 | LR_bb: 1.87e-04
#   Epoch 15 * | Train Loss: 0.2305 | Train Acc: 0.9965 | Val Loss: 0.6958 | Val Acc: 0.7301 | Val mF1: 0.7298 | LR_bb: 1.85e-04
#          Val tahmin: CN=143, EMCI=146
#   Epoch 16   | Train Loss: 0.2293 | Train Acc: 0.9953 | Val Loss: 0.7787 | Val Acc: 0.6817 | Val mF1: 0.6745 | LR_bb: 1.83e-04
#   Epoch 17   | Train Loss: 0.2290 | Train Acc: 0.9982 | Val Loss: 0.7236 | Val Acc: 0.7163 | Val mF1: 0.7134 | LR_bb: 1.81e-04
#   Epoch 18   | Train Loss: 0.2302 | Train Acc: 0.9976 | Val Loss: 0.6991 | Val Acc: 0.7128 | Val mF1: 0.7128 | LR_bb: 1.79e-04
#   Epoch 19 * | Train Loss: 0.2279 | Train Acc: 0.9988 | Val Loss: 0.6561 | Val Acc: 0.7509 | Val mF1: 0.7508 | LR_bb: 1.76e-04
#   Epoch 20   | Train Loss: 0.2264 | Train Acc: 0.9988 | Val Loss: 0.7109 | Val Acc: 0.7232 | Val mF1: 0.7207 | LR_bb: 1.74e-04
#   Epoch 21   | Train Loss: 0.2280 | Train Acc: 0.9982 | Val Loss: 0.6869 | Val Acc: 0.7024 | Val mF1: 0.7018 | LR_bb: 1.71e-04
#   Epoch 22   | Train Loss: 0.2313 | Train Acc: 0.9971 | Val Loss: 0.7066 | Val Acc: 0.7232 | Val mF1: 0.7150 | LR_bb: 1.68e-04
#   Epoch 23   | Train Loss: 0.2305 | Train Acc: 0.9947 | Val Loss: 0.7316 | Val Acc: 0.7197 | Val mF1: 0.7171 | LR_bb: 1.65e-04
#   Epoch 24   | Train Loss: 0.2253 | Train Acc: 0.9988 | Val Loss: 0.7180 | Val Acc: 0.6747 | Val mF1: 0.6736 | LR_bb: 1.62e-04
#   Epoch 25   | Train Loss: 0.2282 | Train Acc: 0.9965 | Val Loss: 0.7389 | Val Acc: 0.7093 | Val mF1: 0.7089 | LR_bb: 1.59e-04
#   Epoch 26   | Train Loss: 0.2268 | Train Acc: 0.9988 | Val Loss: 0.7830 | Val Acc: 0.6678 | Val mF1: 0.6634 | LR_bb: 1.56e-04
#   Epoch 27   | Train Loss: 0.2246 | Train Acc: 0.9982 | Val Loss: 0.7965 | Val Acc: 0.6851 | Val mF1: 0.6847 | LR_bb: 1.52e-04
#   Epoch 28   | Train Loss: 0.2290 | Train Acc: 0.9976 | Val Loss: 0.8229 | Val Acc: 0.6713 | Val mF1: 0.6635 | LR_bb: 1.49e-04
#   Epoch 29   | Train Loss: 0.2249 | Train Acc: 0.9982 | Val Loss: 0.7658 | Val Acc: 0.6955 | Val mF1: 0.6932 | LR_bb: 1.46e-04
#   Epoch 30   | Train Loss: 0.2247 | Train Acc: 0.9988 | Val Loss: 0.7502 | Val Acc: 0.6955 | Val mF1: 0.6932 | LR_bb: 1.42e-04
#   Epoch 31   | Train Loss: 0.2296 | Train Acc: 0.9971 | Val Loss: 0.7243 | Val Acc: 0.7301 | Val mF1: 0.7298 | LR_bb: 1.39e-04
#   Sabir tukendi, Fold 4 durduruldu (epoch 31).
# FOLD 4 VALIDATION SONUCLARI [AKSIYAL]
#   Val Accuracy  : 0.7509
#   Precision     : 0.7560
#   Recall        : 0.7509
#   F1 Score      : 0.7511
#   Per-Class F1  : CN=0.7551 | EMCI=0.7465 | Fark=0.0086 Normal
#   Best Val Loss : 0.6561
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_4.pth
#
# ======================================================================
# FOLD 5 [AKSIYAL]
#   Train: 396 hasta / 1714 seans
#   Val  : 70 hasta / 276 seans
#   Train: CN=923 (53.9%) | EMCI=791 (46.1%)
#   Val: CN=120 (43.5%) | EMCI=156 (56.5%)
# ======================================================================
# Class Weights: CN=0.928, EMCI=1.083
# [AKSIYAL] Toplam param   : 7,216,770
# [AKSIYAL] Egitilen param : 2,423,042 (33.58%)
# [AKSIYAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6689 | Train Acc: 0.5974 | Val Loss: 0.6006 | Val Acc: 0.7138 | Val mF1: 0.6922 | LR_bb: 2.00e-04
#          Val tahmin: CN=83, EMCI=193
#   Epoch 02   | Train Loss: 0.4797 | Train Acc: 0.8215 | Val Loss: 0.7414 | Val Acc: 0.6739 | Val mF1: 0.6311 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3472 | Train Acc: 0.9236 | Val Loss: 0.9782 | Val Acc: 0.6268 | Val mF1: 0.5579 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2735 | Train Acc: 0.9720 | Val Loss: 0.9070 | Val Acc: 0.5978 | Val mF1: 0.5963 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2681 | Train Acc: 0.9761 | Val Loss: 0.7970 | Val Acc: 0.6268 | Val mF1: 0.6267 | LR_bb: 1.99e-04
#          Val tahmin: CN=161, EMCI=115
#   Epoch 06   | Train Loss: 0.2518 | Train Acc: 0.9918 | Val Loss: 0.6911 | Val Acc: 0.6848 | Val mF1: 0.6727 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2386 | Train Acc: 0.9965 | Val Loss: 0.7613 | Val Acc: 0.6413 | Val mF1: 0.6188 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2357 | Train Acc: 0.9953 | Val Loss: 0.7347 | Val Acc: 0.6413 | Val mF1: 0.6411 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2345 | Train Acc: 0.9965 | Val Loss: 0.7327 | Val Acc: 0.6051 | Val mF1: 0.6044 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2354 | Train Acc: 0.9977 | Val Loss: 0.8017 | Val Acc: 0.5978 | Val mF1: 0.5978 | LR_bb: 1.94e-04
#          Val tahmin: CN=155, EMCI=121
#   Epoch 11   | Train Loss: 0.2330 | Train Acc: 0.9977 | Val Loss: 0.8112 | Val Acc: 0.5688 | Val mF1: 0.5653 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2330 | Train Acc: 0.9977 | Val Loss: 0.7436 | Val Acc: 0.6196 | Val mF1: 0.6133 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2319 | Train Acc: 0.9977 | Val Loss: 0.7800 | Val Acc: 0.6014 | Val mF1: 0.6014 | LR_bb: 1.89e-04
#   Sabir tukendi, Fold 5 durduruldu (epoch 13).
# FOLD 5 VALIDATION SONUCLARI [AKSIYAL]
#   Val Accuracy  : 0.7138
#   Precision     : 0.7201
#   Recall        : 0.7138
#   F1 Score      : 0.7029
#   Per-Class F1  : CN=0.6108 | EMCI=0.7736 | Fark=0.1628 KONTROL ET
#   Best Val Loss : 0.6006
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_5.pth
#
# AKSIYAL 5-FOLD VALIDATION SONUCLARI:
#  fold  val_acc   val_f1  best_val_loss
#     1 0.699301 0.696217       0.637110
#     2 0.618705 0.612159       0.637567
#     3 0.681529 0.681012       0.760600
#     4 0.750865 0.751104       0.656113
#     5 0.713768 0.702856       0.600566
# Ortalama Val Acc: 0.6928 +/- 0.0487
# Sure: 28.1 dakika

# %%
import time

koronal_klasoru = os.path.join(ANA_KLASOR, "Koronal")

print(f"EGITIM 3/3: KORONAL")
print(f"Klasor: {koronal_klasoru}\n")

t0 = time.time()
sonuclar_koronal = duzlem_egit(tum_veriler, 'koronal', CONFIG, koronal_klasoru)
sure_koronal = time.time() - t0

df_koronal = pd.read_csv(os.path.join(koronal_klasoru, 'deney_sonuclari.csv'))
print(f"\nKORONAL 5-FOLD VALIDATION SONUCLARI:")
print(df_koronal[['fold', 'val_acc', 'val_f1', 'best_val_loss']].to_string(index=False))
print(f"Ortalama Val Acc: {df_koronal['val_acc'].mean():.4f} +/- {df_koronal['val_acc'].std():.4f}")
print(f"Sure: {sure_koronal/60:.1f} dakika")
# Out:
# EGITIM 3/3: KORONAL
# Klasor: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal
#
#
# ======================================================================
# DUZLEM: KORONAL
# Klasor: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal
# ======================================================================
#
# ======================================================================
# FOLD 1 [KORONAL]
#   Train: 396 hasta / 1704 seans
#   Val  : 70 hasta / 286 seans
#   Train: CN=903 (53.0%) | EMCI=801 (47.0%)
#   Val: CN=140 (49.0%) | EMCI=146 (51.0%)
# ======================================================================
# Class Weights: CN=0.944, EMCI=1.064
# [KORONAL] Toplam param   : 7,216,770
# [KORONAL] Egitilen param : 2,423,042 (33.58%)
# [KORONAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6578 | Train Acc: 0.6285 | Val Loss: 0.6363 | Val Acc: 0.6643 | Val mF1: 0.6576 | LR_bb: 2.00e-04
#          Val tahmin: CN=106, EMCI=180
#   Epoch 02   | Train Loss: 0.4519 | Train Acc: 0.8415 | Val Loss: 1.2851 | Val Acc: 0.5944 | Val mF1: 0.5042 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3274 | Train Acc: 0.9349 | Val Loss: 0.8242 | Val Acc: 0.6049 | Val mF1: 0.6043 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2895 | Train Acc: 0.9660 | Val Loss: 0.9349 | Val Acc: 0.5699 | Val mF1: 0.5687 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2603 | Train Acc: 0.9818 | Val Loss: 0.8150 | Val Acc: 0.6259 | Val mF1: 0.6172 | LR_bb: 1.99e-04
#          Val tahmin: CN=103, EMCI=183
#   Epoch 06   | Train Loss: 0.2497 | Train Acc: 0.9906 | Val Loss: 0.8353 | Val Acc: 0.6119 | Val mF1: 0.6045 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2450 | Train Acc: 0.9924 | Val Loss: 0.8859 | Val Acc: 0.5420 | Val mF1: 0.5281 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2390 | Train Acc: 0.9935 | Val Loss: 1.0506 | Val Acc: 0.5350 | Val mF1: 0.5143 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2388 | Train Acc: 0.9953 | Val Loss: 0.9451 | Val Acc: 0.5315 | Val mF1: 0.5034 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2347 | Train Acc: 0.9971 | Val Loss: 0.8861 | Val Acc: 0.5455 | Val mF1: 0.5436 | LR_bb: 1.94e-04
#          Val tahmin: CN=164, EMCI=122
#   Epoch 11   | Train Loss: 0.2324 | Train Acc: 0.9965 | Val Loss: 0.8367 | Val Acc: 0.6399 | Val mF1: 0.6315 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2414 | Train Acc: 0.9959 | Val Loss: 0.9784 | Val Acc: 0.5490 | Val mF1: 0.5303 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2291 | Train Acc: 0.9977 | Val Loss: 0.8963 | Val Acc: 0.5699 | Val mF1: 0.5634 | LR_bb: 1.89e-04
#   Sabir tukendi, Fold 1 durduruldu (epoch 13).
# FOLD 1 VALIDATION SONUCLARI [KORONAL]
#   Val Accuracy  : 0.6643
#   Precision     : 0.6725
#   Recall        : 0.6643
#   F1 Score      : 0.6586
#   Per-Class F1  : CN=0.6098 | EMCI=0.7055 | Fark=0.0958 Normal
#   Best Val Loss : 0.6363
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_1.pth
#
# ======================================================================
# FOLD 2 [KORONAL]
#   Train: 396 hasta / 1712 seans
#   Val  : 70 hasta / 278 seans
#   Train: CN=881 (51.5%) | EMCI=831 (48.5%)
#   Val: CN=162 (58.3%) | EMCI=116 (41.7%)
# ======================================================================
# Class Weights: CN=0.972, EMCI=1.030
# [KORONAL] Toplam param   : 7,216,770
# [KORONAL] Egitilen param : 2,423,042 (33.58%)
# [KORONAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6809 | Train Acc: 0.6443 | Val Loss: 0.6882 | Val Acc: 0.6187 | Val mF1: 0.5448 | LR_bb: 2.00e-04
#          Val tahmin: CN=228, EMCI=50
#   Epoch 02 * | Train Loss: 0.4711 | Train Acc: 0.8189 | Val Loss: 0.6455 | Val Acc: 0.7050 | Val mF1: 0.7048 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3506 | Train Acc: 0.9206 | Val Loss: 0.7050 | Val Acc: 0.7014 | Val mF1: 0.7000 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2855 | Train Acc: 0.9650 | Val Loss: 0.8706 | Val Acc: 0.6475 | Val mF1: 0.6448 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2624 | Train Acc: 0.9790 | Val Loss: 0.7958 | Val Acc: 0.7050 | Val mF1: 0.6994 | LR_bb: 1.99e-04
#          Val tahmin: CN=154, EMCI=124
#   Epoch 06   | Train Loss: 0.2466 | Train Acc: 0.9930 | Val Loss: 0.7377 | Val Acc: 0.6871 | Val mF1: 0.6859 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2409 | Train Acc: 0.9912 | Val Loss: 0.8074 | Val Acc: 0.6691 | Val mF1: 0.6690 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2389 | Train Acc: 0.9924 | Val Loss: 0.7326 | Val Acc: 0.7050 | Val mF1: 0.7043 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2364 | Train Acc: 0.9930 | Val Loss: 0.7719 | Val Acc: 0.6799 | Val mF1: 0.6795 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2280 | Train Acc: 0.9965 | Val Loss: 0.7366 | Val Acc: 0.6727 | Val mF1: 0.6727 | LR_bb: 1.94e-04
#          Val tahmin: CN=117, EMCI=161
#   Epoch 11   | Train Loss: 0.2286 | Train Acc: 0.9977 | Val Loss: 0.6537 | Val Acc: 0.6978 | Val mF1: 0.6959 | LR_bb: 1.92e-04
#   Epoch 12 * | Train Loss: 0.2291 | Train Acc: 0.9977 | Val Loss: 0.6966 | Val Acc: 0.7194 | Val mF1: 0.7192 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2310 | Train Acc: 0.9947 | Val Loss: 0.7121 | Val Acc: 0.6871 | Val mF1: 0.6808 | LR_bb: 1.89e-04
#   Epoch 14   | Train Loss: 0.2280 | Train Acc: 0.9947 | Val Loss: 0.7110 | Val Acc: 0.6835 | Val mF1: 0.6657 | LR_bb: 1.87e-04
#   Epoch 15   | Train Loss: 0.2261 | Train Acc: 0.9988 | Val Loss: 0.8117 | Val Acc: 0.6475 | Val mF1: 0.6062 | LR_bb: 1.85e-04
#          Val tahmin: CN=206, EMCI=72
#   Epoch 16   | Train Loss: 0.2311 | Train Acc: 0.9971 | Val Loss: 0.7827 | Val Acc: 0.6727 | Val mF1: 0.6714 | LR_bb: 1.83e-04
#   Epoch 17   | Train Loss: 0.2246 | Train Acc: 0.9982 | Val Loss: 0.7242 | Val Acc: 0.7050 | Val mF1: 0.7049 | LR_bb: 1.81e-04
#   Epoch 18   | Train Loss: 0.2236 | Train Acc: 0.9977 | Val Loss: 0.6960 | Val Acc: 0.6978 | Val mF1: 0.6947 | LR_bb: 1.79e-04
#   Epoch 19   | Train Loss: 0.2245 | Train Acc: 0.9982 | Val Loss: 0.7258 | Val Acc: 0.7122 | Val mF1: 0.7122 | LR_bb: 1.76e-04
#   Epoch 20   | Train Loss: 0.2243 | Train Acc: 0.9965 | Val Loss: 0.7753 | Val Acc: 0.6691 | Val mF1: 0.6438 | LR_bb: 1.74e-04
#   Epoch 21 * | Train Loss: 0.2224 | Train Acc: 0.9994 | Val Loss: 0.7013 | Val Acc: 0.7194 | Val mF1: 0.7194 | LR_bb: 1.71e-04
#   Epoch 22   | Train Loss: 0.2208 | Train Acc: 0.9982 | Val Loss: 0.7256 | Val Acc: 0.6978 | Val mF1: 0.6952 | LR_bb: 1.68e-04
#   Epoch 23   | Train Loss: 0.2226 | Train Acc: 0.9982 | Val Loss: 0.7766 | Val Acc: 0.6619 | Val mF1: 0.6607 | LR_bb: 1.65e-04
#   Epoch 24   | Train Loss: 0.2210 | Train Acc: 0.9982 | Val Loss: 0.8556 | Val Acc: 0.6331 | Val mF1: 0.5981 | LR_bb: 1.62e-04
#   Epoch 25   | Train Loss: 0.2210 | Train Acc: 0.9971 | Val Loss: 0.7437 | Val Acc: 0.6727 | Val mF1: 0.6708 | LR_bb: 1.59e-04
#   Epoch 26   | Train Loss: 0.2186 | Train Acc: 0.9988 | Val Loss: 0.7889 | Val Acc: 0.6727 | Val mF1: 0.6704 | LR_bb: 1.56e-04
#   Epoch 27   | Train Loss: 0.2209 | Train Acc: 0.9988 | Val Loss: 0.8118 | Val Acc: 0.6655 | Val mF1: 0.6647 | LR_bb: 1.52e-04
#   Epoch 28   | Train Loss: 0.2177 | Train Acc: 1.0000 | Val Loss: 0.7419 | Val Acc: 0.7194 | Val mF1: 0.7194 | LR_bb: 1.49e-04
#   Epoch 29   | Train Loss: 0.2196 | Train Acc: 0.9988 | Val Loss: 0.7458 | Val Acc: 0.6978 | Val mF1: 0.6978 | LR_bb: 1.46e-04
#   Epoch 30   | Train Loss: 0.2194 | Train Acc: 0.9988 | Val Loss: 0.7512 | Val Acc: 0.6978 | Val mF1: 0.6959 | LR_bb: 1.42e-04
#   Epoch 31   | Train Loss: 0.2205 | Train Acc: 0.9971 | Val Loss: 0.6848 | Val Acc: 0.7050 | Val mF1: 0.7020 | LR_bb: 1.39e-04
#   Epoch 32   | Train Loss: 0.2190 | Train Acc: 0.9977 | Val Loss: 0.7739 | Val Acc: 0.7014 | Val mF1: 0.6919 | LR_bb: 1.35e-04
#   Epoch 33   | Train Loss: 0.2170 | Train Acc: 0.9994 | Val Loss: 0.7015 | Val Acc: 0.7194 | Val mF1: 0.7187 | LR_bb: 1.31e-04
#   Sabir tukendi, Fold 2 durduruldu (epoch 33).
# FOLD 2 VALIDATION SONUCLARI [KORONAL]
#   Val Accuracy  : 0.7194
#   Precision     : 0.7599
#   Recall        : 0.7194
#   F1 Score      : 0.7194
#   Per-Class F1  : CN=0.7194 | EMCI=0.7194 | Fark=0.0000 Normal
#   Best Val Loss : 0.7013
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_2.pth
#
# ======================================================================
# FOLD 3 [KORONAL]
#   Train: 396 hasta / 1676 seans
#   Val  : 70 hasta / 314 seans
#   Train: CN=868 (51.8%) | EMCI=808 (48.2%)
#   Val: CN=175 (55.7%) | EMCI=139 (44.3%)
# ======================================================================
# Class Weights: CN=0.965, EMCI=1.037
# [KORONAL] Toplam param   : 7,216,770
# [KORONAL] Egitilen param : 2,423,042 (33.58%)
# [KORONAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6535 | Train Acc: 0.6295 | Val Loss: 0.6285 | Val Acc: 0.6178 | Val mF1: 0.6023 | LR_bb: 2.00e-04
#          Val tahmin: CN=201, EMCI=113
#   Epoch 02   | Train Loss: 0.4827 | Train Acc: 0.8210 | Val Loss: 0.9564 | Val Acc: 0.5924 | Val mF1: 0.5921 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3597 | Train Acc: 0.9117 | Val Loss: 0.8911 | Val Acc: 0.6083 | Val mF1: 0.5724 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2898 | Train Acc: 0.9618 | Val Loss: 0.8613 | Val Acc: 0.6115 | Val mF1: 0.5656 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2560 | Train Acc: 0.9833 | Val Loss: 0.8756 | Val Acc: 0.6338 | Val mF1: 0.5933 | LR_bb: 1.99e-04
#          Val tahmin: CN=238, EMCI=76
#   Epoch 06   | Train Loss: 0.2442 | Train Acc: 0.9916 | Val Loss: 0.8516 | Val Acc: 0.5732 | Val mF1: 0.5482 | LR_bb: 1.98e-04
#   Epoch 07 * | Train Loss: 0.2468 | Train Acc: 0.9887 | Val Loss: 0.6973 | Val Acc: 0.6497 | Val mF1: 0.6465 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2370 | Train Acc: 0.9952 | Val Loss: 0.8684 | Val Acc: 0.6115 | Val mF1: 0.6037 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2383 | Train Acc: 0.9940 | Val Loss: 0.8303 | Val Acc: 0.6338 | Val mF1: 0.6337 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2327 | Train Acc: 0.9970 | Val Loss: 0.9282 | Val Acc: 0.6401 | Val mF1: 0.5866 | LR_bb: 1.94e-04
#          Val tahmin: CN=252, EMCI=62
#   Epoch 11 * | Train Loss: 0.2348 | Train Acc: 0.9958 | Val Loss: 0.7291 | Val Acc: 0.6497 | Val mF1: 0.6480 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2348 | Train Acc: 0.9952 | Val Loss: 0.8250 | Val Acc: 0.6242 | Val mF1: 0.5922 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2341 | Train Acc: 0.9964 | Val Loss: 0.7767 | Val Acc: 0.6146 | Val mF1: 0.6103 | LR_bb: 1.89e-04
#   Epoch 14   | Train Loss: 0.2320 | Train Acc: 0.9970 | Val Loss: 0.7495 | Val Acc: 0.6369 | Val mF1: 0.6364 | LR_bb: 1.87e-04
#   Epoch 15   | Train Loss: 0.2267 | Train Acc: 0.9988 | Val Loss: 0.7989 | Val Acc: 0.6465 | Val mF1: 0.6109 | LR_bb: 1.85e-04
#          Val tahmin: CN=234, EMCI=80
#   Epoch 16   | Train Loss: 0.2297 | Train Acc: 0.9976 | Val Loss: 0.8523 | Val Acc: 0.6242 | Val mF1: 0.5818 | LR_bb: 1.83e-04
#   Epoch 17 * | Train Loss: 0.2286 | Train Acc: 0.9970 | Val Loss: 0.7664 | Val Acc: 0.6561 | Val mF1: 0.6555 | LR_bb: 1.81e-04
#   Epoch 18 * | Train Loss: 0.2270 | Train Acc: 0.9988 | Val Loss: 0.7492 | Val Acc: 0.6624 | Val mF1: 0.6621 | LR_bb: 1.79e-04
#   Epoch 19   | Train Loss: 0.2240 | Train Acc: 0.9988 | Val Loss: 0.7898 | Val Acc: 0.6401 | Val mF1: 0.6393 | LR_bb: 1.76e-04
#   Epoch 20   | Train Loss: 0.2245 | Train Acc: 0.9988 | Val Loss: 0.7217 | Val Acc: 0.6592 | Val mF1: 0.6476 | LR_bb: 1.74e-04
#   Epoch 21   | Train Loss: 0.2292 | Train Acc: 0.9976 | Val Loss: 0.8315 | Val Acc: 0.6592 | Val mF1: 0.6587 | LR_bb: 1.71e-04
#   Epoch 22   | Train Loss: 0.2275 | Train Acc: 0.9958 | Val Loss: 0.7419 | Val Acc: 0.6624 | Val mF1: 0.6615 | LR_bb: 1.68e-04
#   Epoch 23   | Train Loss: 0.2235 | Train Acc: 0.9988 | Val Loss: 0.7693 | Val Acc: 0.6242 | Val mF1: 0.6057 | LR_bb: 1.65e-04
#   Epoch 24   | Train Loss: 0.2242 | Train Acc: 0.9988 | Val Loss: 0.8221 | Val Acc: 0.6338 | Val mF1: 0.6338 | LR_bb: 1.62e-04
#   Epoch 25   | Train Loss: 0.2214 | Train Acc: 0.9988 | Val Loss: 0.8123 | Val Acc: 0.6210 | Val mF1: 0.6186 | LR_bb: 1.59e-04
#   Epoch 26 * | Train Loss: 0.2222 | Train Acc: 0.9982 | Val Loss: 0.7816 | Val Acc: 0.6911 | Val mF1: 0.6884 | LR_bb: 1.56e-04
#   Epoch 27   | Train Loss: 0.2230 | Train Acc: 0.9994 | Val Loss: 0.8179 | Val Acc: 0.6242 | Val mF1: 0.6180 | LR_bb: 1.52e-04
#   Epoch 28   | Train Loss: 0.2199 | Train Acc: 0.9988 | Val Loss: 0.7626 | Val Acc: 0.6752 | Val mF1: 0.6747 | LR_bb: 1.49e-04
#   Epoch 29   | Train Loss: 0.2198 | Train Acc: 0.9994 | Val Loss: 0.8068 | Val Acc: 0.6019 | Val mF1: 0.5950 | LR_bb: 1.46e-04
#   Epoch 30   | Train Loss: 0.2183 | Train Acc: 1.0000 | Val Loss: 0.7538 | Val Acc: 0.6592 | Val mF1: 0.6539 | LR_bb: 1.42e-04
#   Epoch 31   | Train Loss: 0.2220 | Train Acc: 0.9976 | Val Loss: 0.7941 | Val Acc: 0.6274 | Val mF1: 0.6165 | LR_bb: 1.39e-04
#   Epoch 32   | Train Loss: 0.2193 | Train Acc: 0.9994 | Val Loss: 0.7679 | Val Acc: 0.6433 | Val mF1: 0.6396 | LR_bb: 1.35e-04
#   Epoch 33   | Train Loss: 0.2211 | Train Acc: 0.9982 | Val Loss: 0.7951 | Val Acc: 0.6178 | Val mF1: 0.6034 | LR_bb: 1.31e-04
#   Epoch 34   | Train Loss: 0.2224 | Train Acc: 0.9970 | Val Loss: 0.7624 | Val Acc: 0.6656 | Val mF1: 0.6627 | LR_bb: 1.28e-04
#   Epoch 35   | Train Loss: 0.2165 | Train Acc: 1.0000 | Val Loss: 0.7588 | Val Acc: 0.6592 | Val mF1: 0.6587 | LR_bb: 1.24e-04
#   Epoch 36 * | Train Loss: 0.2193 | Train Acc: 0.9994 | Val Loss: 0.7699 | Val Acc: 0.6911 | Val mF1: 0.6894 | LR_bb: 1.20e-04
#   Epoch 37   | Train Loss: 0.2180 | Train Acc: 1.0000 | Val Loss: 0.7199 | Val Acc: 0.6720 | Val mF1: 0.6687 | LR_bb: 1.16e-04
#   Epoch 38   | Train Loss: 0.2182 | Train Acc: 0.9994 | Val Loss: 0.7455 | Val Acc: 0.6624 | Val mF1: 0.6496 | LR_bb: 1.12e-04
#   Epoch 39   | Train Loss: 0.2178 | Train Acc: 1.0000 | Val Loss: 0.7689 | Val Acc: 0.6752 | Val mF1: 0.6718 | LR_bb: 1.08e-04
#   Epoch 40   | Train Loss: 0.2189 | Train Acc: 0.9994 | Val Loss: 0.7875 | Val Acc: 0.6401 | Val mF1: 0.6296 | LR_bb: 1.04e-04
#   Epoch 41   | Train Loss: 0.2178 | Train Acc: 1.0000 | Val Loss: 0.7978 | Val Acc: 0.6369 | Val mF1: 0.6267 | LR_bb: 1.01e-04
#   Epoch 42   | Train Loss: 0.2174 | Train Acc: 0.9994 | Val Loss: 0.7690 | Val Acc: 0.6465 | Val mF1: 0.6435 | LR_bb: 9.66e-05
#   Epoch 43   | Train Loss: 0.2172 | Train Acc: 1.0000 | Val Loss: 0.7316 | Val Acc: 0.6624 | Val mF1: 0.6543 | LR_bb: 9.27e-05
#   Epoch 44   | Train Loss: 0.2163 | Train Acc: 1.0000 | Val Loss: 0.7853 | Val Acc: 0.6242 | Val mF1: 0.6197 | LR_bb: 8.88e-05
#   Epoch 45   | Train Loss: 0.2158 | Train Acc: 1.0000 | Val Loss: 0.7489 | Val Acc: 0.6561 | Val mF1: 0.6485 | LR_bb: 8.49e-05
#   Epoch 46   | Train Loss: 0.2156 | Train Acc: 0.9994 | Val Loss: 0.7691 | Val Acc: 0.6592 | Val mF1: 0.6563 | LR_bb: 8.11e-05
#   Epoch 47   | Train Loss: 0.2166 | Train Acc: 1.0000 | Val Loss: 0.7612 | Val Acc: 0.6433 | Val mF1: 0.6268 | LR_bb: 7.73e-05
#   Epoch 48   | Train Loss: 0.2177 | Train Acc: 0.9976 | Val Loss: 0.8021 | Val Acc: 0.6369 | Val mF1: 0.6202 | LR_bb: 7.35e-05
#   Sabir tukendi, Fold 3 durduruldu (epoch 48).
# FOLD 3 VALIDATION SONUCLARI [KORONAL]
#   Val Accuracy  : 0.6911
#   Precision     : 0.7343
#   Recall        : 0.6911
#   F1 Score      : 0.6868
#   Per-Class F1  : CN=0.6667 | EMCI=0.7122 | Fark=0.0455 Normal
#   Best Val Loss : 0.7699
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_3.pth
#
# ======================================================================
# FOLD 4 [KORONAL]
#   Train: 396 hasta / 1701 seans
#   Val  : 70 hasta / 289 seans
#   Train: CN=888 (52.2%) | EMCI=813 (47.8%)
#   Val: CN=155 (53.6%) | EMCI=134 (46.4%)
# ======================================================================
# Class Weights: CN=0.958, EMCI=1.046
# [KORONAL] Toplam param   : 7,216,770
# [KORONAL] Egitilen param : 2,423,042 (33.58%)
# [KORONAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6537 | Train Acc: 0.6355 | Val Loss: 0.5935 | Val Acc: 0.6990 | Val mF1: 0.6989 | LR_bb: 2.00e-04
#          Val tahmin: CN=136, EMCI=153
#   Epoch 02   | Train Loss: 0.4770 | Train Acc: 0.8101 | Val Loss: 0.7511 | Val Acc: 0.6159 | Val mF1: 0.6099 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3316 | Train Acc: 0.9312 | Val Loss: 0.9701 | Val Acc: 0.5779 | Val mF1: 0.5736 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2841 | Train Acc: 0.9647 | Val Loss: 0.8047 | Val Acc: 0.6990 | Val mF1: 0.6925 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2721 | Train Acc: 0.9765 | Val Loss: 0.9032 | Val Acc: 0.6401 | Val mF1: 0.6392 | LR_bb: 1.99e-04
#          Val tahmin: CN=119, EMCI=170
#   Epoch 06   | Train Loss: 0.2601 | Train Acc: 0.9853 | Val Loss: 0.8699 | Val Acc: 0.6471 | Val mF1: 0.6458 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2542 | Train Acc: 0.9859 | Val Loss: 0.9517 | Val Acc: 0.5986 | Val mF1: 0.5986 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2382 | Train Acc: 0.9971 | Val Loss: 0.8620 | Val Acc: 0.6159 | Val mF1: 0.6159 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2424 | Train Acc: 0.9941 | Val Loss: 0.8698 | Val Acc: 0.6367 | Val mF1: 0.6337 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2390 | Train Acc: 0.9941 | Val Loss: 0.8152 | Val Acc: 0.6540 | Val mF1: 0.6540 | LR_bb: 1.94e-04
#          Val tahmin: CN=135, EMCI=154
#   Epoch 11   | Train Loss: 0.2472 | Train Acc: 0.9877 | Val Loss: 0.9032 | Val Acc: 0.6298 | Val mF1: 0.6174 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2357 | Train Acc: 0.9947 | Val Loss: 0.9228 | Val Acc: 0.6055 | Val mF1: 0.5948 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2336 | Train Acc: 0.9976 | Val Loss: 0.8534 | Val Acc: 0.6055 | Val mF1: 0.6050 | LR_bb: 1.89e-04
#   Sabir tukendi, Fold 4 durduruldu (epoch 13).
# FOLD 4 VALIDATION SONUCLARI [KORONAL]
#   Val Accuracy  : 0.6990
#   Precision     : 0.7053
#   Recall        : 0.6990
#   F1 Score      : 0.6991
#   Per-Class F1  : CN=0.7010 | EMCI=0.6969 | Fark=0.0042 Normal
#   Best Val Loss : 0.5935
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_4.pth
#
# ======================================================================
# FOLD 5 [KORONAL]
#   Train: 396 hasta / 1714 seans
#   Val  : 70 hasta / 276 seans
#   Train: CN=923 (53.9%) | EMCI=791 (46.1%)
#   Val: CN=120 (43.5%) | EMCI=156 (56.5%)
# ======================================================================
# Class Weights: CN=0.928, EMCI=1.083
# [KORONAL] Toplam param   : 7,216,770
# [KORONAL] Egitilen param : 2,423,042 (33.58%)
# [KORONAL] Dropout        : 0.6
#   Epoch 01 * | Train Loss: 0.6648 | Train Acc: 0.6231 | Val Loss: 0.5959 | Val Acc: 0.7029 | Val mF1: 0.6993 | LR_bb: 2.00e-04
#          Val tahmin: CN=126, EMCI=150
#   Epoch 02   | Train Loss: 0.5052 | Train Acc: 0.7981 | Val Loss: 0.7684 | Val Acc: 0.6667 | Val mF1: 0.6010 | LR_bb: 2.00e-04
#   Epoch 03   | Train Loss: 0.3615 | Train Acc: 0.9172 | Val Loss: 1.1876 | Val Acc: 0.6413 | Val mF1: 0.5627 | LR_bb: 2.00e-04
#   Epoch 04   | Train Loss: 0.2960 | Train Acc: 0.9644 | Val Loss: 0.7756 | Val Acc: 0.6268 | Val mF1: 0.6267 | LR_bb: 1.99e-04
#   Epoch 05   | Train Loss: 0.2577 | Train Acc: 0.9831 | Val Loss: 0.9796 | Val Acc: 0.5326 | Val mF1: 0.5161 | LR_bb: 1.99e-04
#          Val tahmin: CN=207, EMCI=69
#   Epoch 06   | Train Loss: 0.2584 | Train Acc: 0.9837 | Val Loss: 0.8188 | Val Acc: 0.6703 | Val mF1: 0.6483 | LR_bb: 1.98e-04
#   Epoch 07   | Train Loss: 0.2544 | Train Acc: 0.9883 | Val Loss: 0.7233 | Val Acc: 0.6486 | Val mF1: 0.6435 | LR_bb: 1.97e-04
#   Epoch 08   | Train Loss: 0.2465 | Train Acc: 0.9942 | Val Loss: 0.9715 | Val Acc: 0.6993 | Val mF1: 0.6484 | LR_bb: 1.96e-04
#   Epoch 09   | Train Loss: 0.2609 | Train Acc: 0.9942 | Val Loss: 1.0311 | Val Acc: 0.5000 | Val mF1: 0.4893 | LR_bb: 1.95e-04
#   Epoch 10   | Train Loss: 0.2446 | Train Acc: 0.9971 | Val Loss: 0.8228 | Val Acc: 0.5652 | Val mF1: 0.5649 | LR_bb: 1.94e-04
#          Val tahmin: CN=148, EMCI=128
#   Epoch 11   | Train Loss: 0.2514 | Train Acc: 0.9953 | Val Loss: 0.7825 | Val Acc: 0.5942 | Val mF1: 0.5940 | LR_bb: 1.92e-04
#   Epoch 12   | Train Loss: 0.2536 | Train Acc: 0.9959 | Val Loss: 0.7288 | Val Acc: 0.6630 | Val mF1: 0.6530 | LR_bb: 1.91e-04
#   Epoch 13   | Train Loss: 0.2525 | Train Acc: 0.9936 | Val Loss: 0.7800 | Val Acc: 0.6159 | Val mF1: 0.6150 | LR_bb: 1.89e-04
#   Sabir tukendi, Fold 5 durduruldu (epoch 13).
# FOLD 5 VALIDATION SONUCLARI [KORONAL]
#   Val Accuracy  : 0.7029
#   Precision     : 0.7050
#   Recall        : 0.7029
#   F1 Score      : 0.7036
#   Per-Class F1  : CN=0.6667 | EMCI=0.7320 | Fark=0.0654 Normal
#   Best Val Loss : 0.5959
#   Model kaydi   : /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_5.pth
#
# KORONAL 5-FOLD VALIDATION SONUCLARI:
#  fold  val_acc   val_f1  best_val_loss
#     1 0.664336 0.658643       0.636329
#     2 0.719424 0.719424       0.701275
#     3 0.691083 0.686808       0.769917
#     4 0.698962 0.699099       0.593463
#     5 0.702899 0.703609       0.595917
# Ortalama Val Acc: 0.6953 +/- 0.0202
# Sure: 34.7 dakika

# %%
# ===== TOPLU VALIDATION OZETI (3 duzlem x 5 fold) =====
import pandas as pd, os

# Modeller baska bir oturumda egitildiyse ANA_KLASOR'u elle sabitle:

duzlemler = {
    'Sagital': os.path.join(ANA_KLASOR, 'Sagital', 'deney_sonuclari.csv'),
    'Aksiyal': os.path.join(ANA_KLASOR, 'Aksiyal', 'deney_sonuclari.csv'),
    'Koronal': os.path.join(ANA_KLASOR, 'Koronal', 'deney_sonuclari.csv'),
}

tum_dfler = []
print("="*70)
print("TOPLU VALIDATION SONUCLARI (Per-Plane)")
print("="*70)

for ad, yol in duzlemler.items():
    if not os.path.exists(yol):
        print(f"\n[{ad}] CSV bulunamadi ({yol}) - bu duzlem egitilmemis olabilir.")
        continue
    df = pd.read_csv(yol)
    df['duzlem'] = ad
    tum_dfler.append(df)

    print(f"\n--- {ad.upper()} ---")
    print(df[['fold', 'val_acc', 'val_f1', 'val_f1_cn', 'val_f1_emci', 'best_val_loss']].to_string(index=False))
    print(f"  Ortalama Val Acc : {df['val_acc'].mean():.4f} +/- {df['val_acc'].std():.4f}")
    print(f"  Ortalama Val F1  : {df['val_f1'].mean():.4f}")
    print(f"  CN F1 / EMCI F1  : {df['val_f1_cn'].mean():.4f} / {df['val_f1_emci'].mean():.4f}")

if tum_dfler:
    hepsi = pd.concat(tum_dfler, ignore_index=True)

    print("\n" + "="*70)
    print("DUZLEM BAZLI OZET TABLOSU")
    print("="*70)
    ozet = hepsi.groupby('duzlem').agg(
        val_acc_ort=('val_acc', 'mean'),
        val_acc_std=('val_acc', 'std'),
        val_f1_ort=('val_f1', 'mean'),
        cn_f1=('val_f1_cn', 'mean'),
        emci_f1=('val_f1_emci', 'mean'),
    ).round(4)
    print(ozet.to_string())

    print("\n" + "="*70)
    print("GENEL ORTALAMA (15 model = 3 duzlem x 5 fold)")
    print("="*70)
    print(f"  Val Accuracy : {hepsi['val_acc'].mean():.4f} +/- {hepsi['val_acc'].std():.4f}")
    print(f"  Val F1       : {hepsi['val_f1'].mean():.4f} +/- {hepsi['val_f1'].std():.4f}")
    print(f"  CN F1        : {hepsi['val_f1_cn'].mean():.4f}")
    print(f"  EMCI F1      : {hepsi['val_f1_emci'].mean():.4f}")

    # Gorsel: duzlem bazli fold accuracy
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots(figsize=(9, 4.5))
    renkler = {'Sagital': 'steelblue', 'Aksiyal': 'orange', 'Koronal': 'seagreen'}
    for ad in ['Sagital', 'Aksiyal', 'Koronal']:
        d = hepsi[hepsi['duzlem'] == ad]
        if len(d) == 0: continue
        ax.plot(d['fold'], d['val_acc'], 'o-', label=f"{ad} (ort {d['val_acc'].mean():.3f})",
                color=renkler[ad], lw=2, markersize=8)
    ax.set_xlabel('Fold'); ax.set_ylabel('Validation Accuracy')
    ax.set_title('Per-Plane: Duzlem Bazli Fold Validation Accuracy')
    ax.set_xticks([1,2,3,4,5]); ax.set_ylim([0.4, 1.0])
    ax.legend(); ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(os.path.join(ANA_KLASOR, 'toplu_val_accuracy.png'), dpi=100, bbox_inches='tight')
    plt.show()
else:
    print("\nHic CSV bulunamadi. Once egitimi calistir veya ANA_KLASOR'u dogru klasore sabitle.")
# Out:
# ======================================================================
# TOPLU VALIDATION SONUCLARI (Per-Plane)
# ======================================================================
#
# --- SAGITAL ---
#  fold  val_acc   val_f1  val_f1_cn  val_f1_emci  best_val_loss
#     1 0.737762 0.736747   0.716981     0.755700       0.650737
#     2 0.669065 0.671340   0.693333     0.640625       0.736328
#     3 0.719745 0.720485   0.728395     0.710526       0.689030
#     4 0.761246 0.761401   0.775244     0.745387       0.625868
#     5 0.666667 0.644377   0.510638     0.747253       0.637572
#   Ortalama Val Acc : 0.7109 +/- 0.0420
#   Ortalama Val F1  : 0.7069
#   CN F1 / EMCI F1  : 0.6849 / 0.7199
#
# --- AKSIYAL ---
#  fold  val_acc   val_f1  val_f1_cn  val_f1_emci  best_val_loss
#     1 0.699301 0.696217   0.724359     0.669231       0.637110
#     2 0.618705 0.612159   0.589147     0.644295       0.637567
#     3 0.681529 0.681012   0.677419     0.685535       0.760600
#     4 0.750865 0.751104   0.755102     0.746479       0.656113
#     5 0.713768 0.702856   0.610837     0.773639       0.600566
#   Ortalama Val Acc : 0.6928 +/- 0.0487
#   Ortalama Val F1  : 0.6887
#   CN F1 / EMCI F1  : 0.6714 / 0.7038
#
# --- KORONAL ---
#  fold  val_acc   val_f1  val_f1_cn  val_f1_emci  best_val_loss
#     1 0.664336 0.658643   0.609756     0.705521       0.636329
#     2 0.719424 0.719424   0.719424     0.719424       0.701275
#     3 0.691083 0.686808   0.666667     0.712166       0.769917
#     4 0.698962 0.699099   0.701031     0.696864       0.593463
#     5 0.702899 0.703609   0.666667     0.732026       0.595917
#   Ortalama Val Acc : 0.6953 +/- 0.0202
#   Ortalama Val F1  : 0.6935
#   CN F1 / EMCI F1  : 0.6727 / 0.7132
#
# ======================================================================
# DUZLEM BAZLI OZET TABLOSU
# ======================================================================
#          val_acc_ort  val_acc_std  val_f1_ort   cn_f1  emci_f1
# duzlem
# Aksiyal       0.6928       0.0487      0.6887  0.6714   0.7038
# Koronal       0.6953       0.0202      0.6935  0.6727   0.7132
# Sagital       0.7109       0.0420      0.7069  0.6849   0.7199
#
# ======================================================================
# GENEL ORTALAMA (15 model = 3 duzlem x 5 fold)
# ======================================================================
#   Val Accuracy : 0.6997 +/- 0.0369
#   Val F1       : 0.6964 +/- 0.0399
#   CN F1        : 0.6763
#   EMCI F1      : 0.7123

# %%
# ============================================================
# NIHAI TEST: izole test seti + 15 model agirlikli ensemble
# ============================================================
import numpy as np
ANA_KLASOR = '/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56'


# --- 1) Izole test verisini oku (train ile AYNI yapida) ---
test_config = dict(CONFIG)
test_config["kaynak_CN"]   = CONFIG["kaynak_CN_test"]
test_config["kaynak_EMCI"] = CONFIG["kaynak_EMCI_test"]

test_veriler = veri_listesi_olustur(test_config)
n_cn_te   = sum(1 for x in test_veriler if x['etiket'] == 0)
n_emci_te = sum(1 for x in test_veriler if x['etiket'] == 1)
print(f"TEST seti: {len(test_veriler)} seans  (CN={n_cn_te}, EMCI={n_emci_te})")
assert len(test_veriler) > 0, "Test seti bos! kaynak_CN_test / kaynak_EMCI_test yollarini kontrol et."

# Gercek etiket sozlugu: sid -> etiket
sid_true = {f"{x['hasta_id']}_{x['seans_id']}": x['etiket'] for x in test_veriler}

# --- 2) Ensemble agirliklari (degistirilebilir) ---
DUZLEM_AGIRLIK = {'sagital': 1.0, 'aksiyal': 1.0, 'koronal': 1.0}

DUZLEM_KLASOR = {
    'sagital': os.path.join(ANA_KLASOR, 'Sagital'),
    'aksiyal': os.path.join(ANA_KLASOR, 'Aksiyal'),
    'koronal': os.path.join(ANA_KLASOR, 'Koronal'),
}

# --- 3) Tahmin yardimci fonksiyonu (seans_id ile birlikte) ---
def tahmin_al(model, loader):
    model.eval()
    sids_all, probs_all = [], []
    with torch.no_grad():
        for sids, slices, lbls in loader:
            slices = slices.to(DEVICE)
            logits = model(slices)
            probs  = torch.softmax(logits, dim=1).cpu().numpy()
            sids_all.extend(list(sids))
            probs_all.extend(probs.tolist())
    return sids_all, probs_all

# --- 4) Her duzlem icin 5 fold modelin olasiligini ortala ---
# plane_avg[duzlem][sid] = ortalama [prob_cn, prob_emci]
plane_avg = {}

for duzlem, klasor in DUZLEM_KLASOR.items():
    print(f"\n[{duzlem.upper()}] 5 fold modeli test ediliyor...")
    test_loader = loader_olustur(test_veriler, duzlem, CONFIG, shuffle=False)

    toplam = {}   # sid -> np.array([p_cn, p_emci]) toplam
    for fold in range(1, CONFIG['k_fold'] + 1):
        m_path = os.path.join(klasor, f'{duzlem}_fold_{fold}.pth')
        model = SinglePlaneModel(dropout_rate=CONFIG['dropout'], hidden_dim=256).to(DEVICE)
        model.load_state_dict(torch.load(m_path, weights_only=True))
        sids, probs = tahmin_al(model, test_loader)
        for sid, pr in zip(sids, probs):
            toplam.setdefault(sid, np.zeros(2))
            toplam[sid] += np.array(pr)
        print(f"  fold {fold} tamam ({m_path})")
        del model
        torch.cuda.empty_cache()

    plane_avg[duzlem] = {sid: v / CONFIG['k_fold'] for sid, v in toplam.items()}

# --- 5) Agirlikli ensemble (3 duzlem) ---
toplam_agirlik = sum(DUZLEM_AGIRLIK.values())
ortak_sid = set.intersection(*[set(plane_avg[d].keys()) for d in DUZLEM_KLASOR])
print(f"\nUc duzlemde de tahmin edilen ortak seans: {len(ortak_sid)}")

y_true, y_pred = [], []
y_pred_duzlem = {d: [] for d in DUZLEM_KLASOR}
kayit = []

for sid in sorted(ortak_sid):
    fused = np.zeros(2)
    for d in DUZLEM_KLASOR:
        fused += DUZLEM_AGIRLIK[d] * plane_avg[d][sid]
    fused /= toplam_agirlik

    pred = int(np.argmax(fused))
    true = sid_true[sid]
    y_true.append(true)
    y_pred.append(pred)

    satir = {'seans_id': sid,
             'gercek': 'CN' if true == 0 else 'EMCI',
             'ens_prob_cn': fused[0], 'ens_prob_emci': fused[1],
             'ensemble': 'CN' if pred == 0 else 'EMCI'}
    for d in DUZLEM_KLASOR:
        dp = int(np.argmax(plane_avg[d][sid]))
        y_pred_duzlem[d].append(dp)
        satir[d] = 'CN' if dp == 0 else 'EMCI'
    satir['dogru_mu'] = (true == pred)
    kayit.append(satir)

# --- 6) Metrikler ---
acc = accuracy_score(y_true, y_pred)
p, r, f, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)
p_pc, r_pc, f_pc, _ = precision_recall_fscore_support(
    y_true, y_pred, average=None, labels=[0, 1], zero_division=0
)

print(f"\n{'='*70}")
print("NIHAI TEST SONUCLARI (Agirlikli Ensemble)")
print(f"{'='*70}")
print(f"Agirliklar    : {DUZLEM_AGIRLIK}")
print(f"Test seans    : {len(y_true)}")
print(f"\nTekil duzlem test accuracy:")
for d in DUZLEM_KLASOR:
    print(f"  {d.capitalize():9s}: {accuracy_score(y_true, y_pred_duzlem[d]):.4f}")
print(f"\n  ENSEMBLE Accuracy : {acc:.4f}")
print(f"  Precision         : {p:.4f}")
print(f"  Recall            : {r:.4f}")
print(f"  F1 Score          : {f:.4f}")
print(f"  Per-Class F1      : CN={f_pc[0]:.4f} | EMCI={f_pc[1]:.4f}")

print(f"\n{classification_report(y_true, y_pred, target_names=['CN','EMCI'], zero_division=0)}")

# --- 7) Confusion matrix ---
plt.figure(figsize=(4.5, 3.5))
cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['CN', 'EMCI'], yticklabels=['CN', 'EMCI'])
plt.title("NIHAI TEST — Ensemble Confusion Matrix")
plt.xlabel("Tahmin"); plt.ylabel("Gercek")
plt.tight_layout()
plt.savefig(os.path.join(ANA_KLASOR, 'final_test_confusion_matrix.png'),
            dpi=100, bbox_inches='tight')
plt.show()

# --- 8) Tekil duzlem vs ensemble grafigi ---
fig, axg = plt.subplots(figsize=(7, 4.5))
isimler = [d.capitalize() for d in DUZLEM_KLASOR] + ['ENSEMBLE']
degerler = [accuracy_score(y_true, y_pred_duzlem[d]) for d in DUZLEM_KLASOR] + [acc]
renkler = ['steelblue']*3 + ['crimson']
axg.bar(isimler, degerler, color=renkler, alpha=0.85)
for i, v in enumerate(degerler):
    axg.text(i, v + 0.01, f"{v:.3f}", ha='center', fontweight='bold')
axg.set_ylabel('Test Accuracy'); axg.set_ylim([0, 1])
axg.set_title('Tekil Duzlem vs Ensemble (Izole Test)')
axg.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(ANA_KLASOR, 'final_test_karsilastirma.png'),
            dpi=100, bbox_inches='tight')
plt.show()

# --- 9) Kayit ---
df_kayit = pd.DataFrame(kayit)
df_kayit.to_csv(os.path.join(ANA_KLASOR, 'final_test_tahminler.csv'), index=False)
pd.DataFrame([{
    'agirlik_sag': DUZLEM_AGIRLIK['sagital'],
    'agirlik_ax' : DUZLEM_AGIRLIK['aksiyal'],
    'agirlik_kor': DUZLEM_AGIRLIK['koronal'],
    'test_acc': acc, 'precision': p, 'recall': r, 'f1': f,
    'f1_cn': f_pc[0], 'f1_emci': f_pc[1], 'n_test': len(y_true)
}]).to_csv(os.path.join(ANA_KLASOR, 'final_test_ozet.csv'), index=False)

print(f"\nKaydedildi: final_test_tahminler.csv, final_test_ozet.csv")
print("Bitti.")
# Out:
# TEST seti: 296 seans  (CN=148, EMCI=148)
#
# [SAGITAL] 5 fold modeli test ediliyor...
#   fold 1 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_1.pth)
#   fold 2 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_2.pth)
#   fold 3 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_3.pth)
#   fold 4 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_4.pth)
#   fold 5 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Sagital/sagital_fold_5.pth)
#
# [AKSIYAL] 5 fold modeli test ediliyor...
#   fold 1 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_1.pth)
#   fold 2 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_2.pth)
#   fold 3 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_3.pth)
#   fold 4 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_4.pth)
#   fold 5 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Aksiyal/aksiyal_fold_5.pth)
#
# [KORONAL] 5 fold modeli test ediliyor...
#   fold 1 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_1.pth)
#   fold 2 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_2.pth)
#   fold 3 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_3.pth)
#   fold 4 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_4.pth)
#   fold 5 tamam (/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56/Koronal/koronal_fold_5.pth)
#
# Uc duzlemde de tahmin edilen ortak seans: 296
#
# ======================================================================
# NIHAI TEST SONUCLARI (Agirlikli Ensemble)
# ======================================================================
# Agirliklar    : {'sagital': 1.0, 'aksiyal': 1.0, 'koronal': 1.0}
# Test seans    : 296
#
# Tekil duzlem test accuracy:
#   Sagital  : 0.6351
#   Aksiyal  : 0.6115
#   Koronal  : 0.6149
#
#   ENSEMBLE Accuracy : 0.6182
#   Precision         : 0.6356
#   Recall            : 0.6182
#   F1 Score          : 0.6056
#   Per-Class F1      : CN=0.5350 | EMCI=0.6762
#
#               precision    recall  f1-score   support
#
#           CN       0.68      0.44      0.53       148
#         EMCI       0.59      0.80      0.68       148
#
#     accuracy                           0.62       296
#    macro avg       0.64      0.62      0.61       296
# weighted avg       0.64      0.62      0.61       296
# Kaydedildi: final_test_tahminler.csv, final_test_ozet.csv
# Bitti.

# %%
# --- sonuclari sakla (grafik icin) ---
try: SONUCLAR
except NameError: SONUCLAR = {'duzlem': {}, 'strateji': {}}
for d in DUZLEM_KLASOR:
    SONUCLAR['duzlem'][d.capitalize()] = accuracy_score(y_true, y_pred_duzlem[d])
SONUCLAR['strateji']['3-duzlem\nesit ensemble'] = acc

# %%
# ===== EK HUCRE A: VALIDATION'da en iyi DUZLEMI sec, 5-fold ensemble test =====
import numpy as np, os

# Modeller baska oturumda egitildiyse dogru klasoru sabitle:
ANA_KLASOR ='/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56'

DUZLEM_KLASOR = {
    'sagital': os.path.join(ANA_KLASOR, 'Sagital'),
    'aksiyal': os.path.join(ANA_KLASOR, 'Aksiyal'),
    'koronal': os.path.join(ANA_KLASOR, 'Koronal'),
}

# 1) Her duzlemin VALIDATION ortalamasini oku, en iyisini sec (TEST'e gore DEGIL)
val_ort = {}
for d, klasor in DUZLEM_KLASOR.items():
    dfv = pd.read_csv(os.path.join(klasor, 'deney_sonuclari.csv'))
    val_ort[d] = dfv['val_acc'].mean()
    print(f"  {d.capitalize():9s} val_acc ort: {val_ort[d]:.4f}")
en_iyi_duzlem = max(val_ort, key=val_ort.get)
print(f"\nVALIDATION'da en iyi duzlem: {en_iyi_duzlem.upper()}  ({val_ort[en_iyi_duzlem]:.4f})\n")

# 2) Test verisi
test_config = dict(CONFIG)
test_config["kaynak_CN"]   = CONFIG["kaynak_CN_test"]
test_config["kaynak_EMCI"] = CONFIG["kaynak_EMCI_test"]
test_veriler = veri_listesi_olustur(test_config)
sid_true = {f"{x['hasta_id']}_{x['seans_id']}": x['etiket'] for x in test_veriler}

# 3) Sadece o duzlemin 5 fold modelini ortala
klasor = DUZLEM_KLASOR[en_iyi_duzlem]
test_loader = loader_olustur(test_veriler, en_iyi_duzlem, CONFIG, shuffle=False)
toplam = {}
for fold in range(1, CONFIG['k_fold'] + 1):
    m_path = os.path.join(klasor, f'{en_iyi_duzlem}_fold_{fold}.pth')
    model = SinglePlaneModel(dropout_rate=CONFIG['dropout'], hidden_dim=256).to(DEVICE)
    model.load_state_dict(torch.load(m_path, weights_only=True))
    sids, probs = tahmin_al(model, test_loader)
    for sid, pr in zip(sids, probs):
        toplam.setdefault(sid, np.zeros(2)); toplam[sid] += np.array(pr)
    del model; torch.cuda.empty_cache()
avg = {sid: v / CONFIG['k_fold'] for sid, v in toplam.items()}

# 4) Karar + metrikler
y_true, y_pred = [], []
for sid in sorted(avg.keys()):
    y_true.append(sid_true[sid]); y_pred.append(int(np.argmax(avg[sid])))

acc = accuracy_score(y_true, y_pred)
p, r, f, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)
p_pc, r_pc, f_pc, _ = precision_recall_fscore_support(y_true, y_pred, average=None, labels=[0,1], zero_division=0)
print(f"{'='*60}\nEN IYI DUZLEM ({en_iyi_duzlem.upper()}) 5-FOLD ENSEMBLE — NIHAI TEST\n{'='*60}")
print(f"   Accuracy     : {acc:.4f}")
print(f"   Precision    : {p:.4f} | Recall: {r:.4f} | F1: {f:.4f}")
print(f"   Per-Class F1 : CN={f_pc[0]:.4f} | EMCI={f_pc[1]:.4f}")
print(f"\n{classification_report(y_true, y_pred, target_names=['CN','EMCI'], zero_division=0)}")

plt.figure(figsize=(4,3.2))
sns.heatmap(confusion_matrix(y_true, y_pred, labels=[0,1]), annot=True, fmt='d', cmap='Greens',
            xticklabels=['CN','EMCI'], yticklabels=['CN','EMCI'])
plt.title(f"En Iyi Duzlem ({en_iyi_duzlem.capitalize()}) — Test CM")
plt.xlabel("Tahmin"); plt.ylabel("Gercek"); plt.tight_layout(); plt.show()
# Out:
#   Sagital   val_acc ort: 0.7114
#   Aksiyal   val_acc ort: 0.6803
#   Koronal   val_acc ort: 0.6778
#
# VALIDATION'da en iyi duzlem: SAGITAL  (0.7114)
#
# ============================================================
# EN IYI DUZLEM (SAGITAL) 5-FOLD ENSEMBLE — NIHAI TEST
# ============================================================
#    Accuracy     : 0.6520
#    Precision    : 0.6552 | Recall: 0.6520 | F1: 0.6503
#    Per-Class F1 : CN=0.6255 | EMCI=0.6751
#
#               precision    recall  f1-score   support
#
#           CN       0.68      0.58      0.63       148
#         EMCI       0.63      0.72      0.68       148
#
#     accuracy                           0.65       296
#    macro avg       0.66      0.65      0.65       296
# weighted avg       0.66      0.65      0.65       296

# %%
try: SONUCLAR
except NameError: SONUCLAR = {'duzlem': {}, 'strateji': {}}
SONUCLAR['strateji']['Val-agirlikli\nensemble'] = acc

# %%
# ===== EK HUCRE B: VALIDATION accuracy ile DUZLEM-AGIRLIKLI ensemble =====
import numpy as np, os

ANA_KLASOR ='/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56'


DUZLEM_KLASOR = {
    'sagital': os.path.join(ANA_KLASOR, 'Sagital'),
    'aksiyal': os.path.join(ANA_KLASOR, 'Aksiyal'),
    'koronal': os.path.join(ANA_KLASOR, 'Koronal'),
}

# 1) Agirliklar VALIDATION'dan: (val_acc - 0.5) ile zayif duzlem otomatik kisilir
agirlik = {}
for d, klasor in DUZLEM_KLASOR.items():
    dfv = pd.read_csv(os.path.join(klasor, 'deney_sonuclari.csv'))
    agirlik[d] = max(dfv['val_acc'].mean() - 0.5, 0.0)
toplam_ag = sum(agirlik.values())
agirlik = {d: v / toplam_ag for d, v in agirlik.items()}
print("Duzlem agirliklari (validation'dan):")
for d, w in agirlik.items():
    print(f"   {d.capitalize():9s}: {w:.3f}")

# 2) Test verisi
test_config = dict(CONFIG)
test_config["kaynak_CN"]   = CONFIG["kaynak_CN_test"]
test_config["kaynak_EMCI"] = CONFIG["kaynak_EMCI_test"]
test_veriler = veri_listesi_olustur(test_config)
sid_true = {f"{x['hasta_id']}_{x['seans_id']}": x['etiket'] for x in test_veriler}

# 3) Her duzlemin 5-fold ortalamasini al
plane_avg = {}
for d, klasor in DUZLEM_KLASOR.items():
    test_loader = loader_olustur(test_veriler, d, CONFIG, shuffle=False)
    toplam = {}
    for fold in range(1, CONFIG['k_fold'] + 1):
        m_path = os.path.join(klasor, f'{d}_fold_{fold}.pth')
        model = SinglePlaneModel(dropout_rate=CONFIG['dropout'], hidden_dim=256).to(DEVICE)
        model.load_state_dict(torch.load(m_path, weights_only=True))
        sids, probs = tahmin_al(model, test_loader)
        for sid, pr in zip(sids, probs):
            toplam.setdefault(sid, np.zeros(2)); toplam[sid] += np.array(pr)
        del model; torch.cuda.empty_cache()
    plane_avg[d] = {sid: v / CONFIG['k_fold'] for sid, v in toplam.items()}

# 4) Agirlikli birlesim
ortak = set.intersection(*[set(plane_avg[d].keys()) for d in DUZLEM_KLASOR])
y_true, y_pred = [], []
for sid in sorted(ortak):
    fused = np.zeros(2)
    for d in DUZLEM_KLASOR:
        fused += agirlik[d] * plane_avg[d][sid]
    y_true.append(sid_true[sid]); y_pred.append(int(np.argmax(fused)))

acc = accuracy_score(y_true, y_pred)
p, r, f, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)
p_pc, r_pc, f_pc, _ = precision_recall_fscore_support(y_true, y_pred, average=None, labels=[0,1], zero_division=0)
print(f"\n{'='*60}\nVAL-AGIRLIKLI DUZLEM ENSEMBLE — NIHAI TEST\n{'='*60}")
print(f"   Accuracy     : {acc:.4f}")
print(f"   Precision    : {p:.4f} | Recall: {r:.4f} | F1: {f:.4f}")
print(f"   Per-Class F1 : CN={f_pc[0]:.4f} | EMCI={f_pc[1]:.4f}")
print(f"\n{classification_report(y_true, y_pred, target_names=['CN','EMCI'], zero_division=0)}")

plt.figure(figsize=(4,3.2))
sns.heatmap(confusion_matrix(y_true, y_pred, labels=[0,1]), annot=True, fmt='d', cmap='Purples',
            xticklabels=['CN','EMCI'], yticklabels=['CN','EMCI'])
plt.title("Val-Agirlikli Duzlem Ensemble — Test CM")
plt.xlabel("Tahmin"); plt.ylabel("Gercek"); plt.tight_layout(); plt.show()
# Out:
# Duzlem agirliklari (validation'dan):
#    Sagital  : 0.371
#    Aksiyal  : 0.317
#    Koronal  : 0.312
#
# ============================================================
# VAL-AGIRLIKLI DUZLEM ENSEMBLE — NIHAI TEST
# ============================================================
#    Accuracy     : 0.6216
#    Precision    : 0.6387 | Recall: 0.6216 | F1: 0.6096
#    Per-Class F1 : CN=0.5410 | EMCI=0.6782
#
#               precision    recall  f1-score   support
#
#           CN       0.69      0.45      0.54       148
#         EMCI       0.59      0.80      0.68       148
#
#     accuracy                           0.62       296
#    macro avg       0.64      0.62      0.61       296
# weighted avg       0.64      0.62      0.61       296

# %%
try: SONUCLAR
except NameError: SONUCLAR = {'duzlem': {}, 'strateji': {}}
SONUCLAR['strateji']['15-model\nagirlikli'] = acc

# %%
# ===== EK HUCRE C: 15 MODEL — her (duzlem,fold) modeline KENDI val_acc agirligi =====
import numpy as np, os

ANA_KLASOR ='/content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_08_18_56'


DUZLEM_KLASOR = {
    'sagital': os.path.join(ANA_KLASOR, 'Sagital'),
    'aksiyal': os.path.join(ANA_KLASOR, 'Aksiyal'),
    'koronal': os.path.join(ANA_KLASOR, 'Koronal'),
}

# 1) Her (duzlem,fold) icin VALIDATION agirligi (val_acc - 0.5)
model_agirlik = {}   # (duzlem, fold) -> agirlik
for d, klasor in DUZLEM_KLASOR.items():
    dfv = pd.read_csv(os.path.join(klasor, 'deney_sonuclari.csv'))
    for _, row in dfv.iterrows():
        model_agirlik[(d, int(row['fold']))] = max(row['val_acc'] - 0.5, 0.0)
toplam_ag = sum(model_agirlik.values())
print("15 model agirligi (validation'dan, normalize):")
for (d, fold), w in sorted(model_agirlik.items()):
    print(f"   {d.capitalize():9s} fold {fold}: {w/toplam_ag:.3f}")

# 2) Test verisi
test_config = dict(CONFIG)
test_config["kaynak_CN"]   = CONFIG["kaynak_CN_test"]
test_config["kaynak_EMCI"] = CONFIG["kaynak_EMCI_test"]
test_veriler = veri_listesi_olustur(test_config)
sid_true = {f"{x['hasta_id']}_{x['seans_id']}": x['etiket'] for x in test_veriler}

# 3) 15 modeli tek tek, kendi agirligiyla topla
toplam_olasilik = {}
for d, klasor in DUZLEM_KLASOR.items():
    test_loader = loader_olustur(test_veriler, d, CONFIG, shuffle=False)
    for fold in range(1, CONFIG['k_fold'] + 1):
        m_path = os.path.join(klasor, f'{d}_fold_{fold}.pth')
        model = SinglePlaneModel(dropout_rate=CONFIG['dropout'], hidden_dim=256).to(DEVICE)
        model.load_state_dict(torch.load(m_path, weights_only=True))
        sids, probs = tahmin_al(model, test_loader)
        w = model_agirlik[(d, fold)] / toplam_ag
        for sid, pr in zip(sids, probs):
            toplam_olasilik.setdefault(sid, np.zeros(2))
            toplam_olasilik[sid] += w * np.array(pr)
        del model; torch.cuda.empty_cache()

# 4) Karar + metrikler
y_true, y_pred = [], []
for sid in sorted(toplam_olasilik.keys()):
    y_true.append(sid_true[sid]); y_pred.append(int(np.argmax(toplam_olasilik[sid])))

acc = accuracy_score(y_true, y_pred)
p, r, f, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)
p_pc, r_pc, f_pc, _ = precision_recall_fscore_support(y_true, y_pred, average=None, labels=[0,1], zero_division=0)
print(f"\n{'='*60}\n15-MODEL VAL-AGIRLIKLI ENSEMBLE — NIHAI TEST\n{'='*60}")
print(f"   Accuracy     : {acc:.4f}")
print(f"   Precision    : {p:.4f} | Recall: {r:.4f} | F1: {f:.4f}")
print(f"   Per-Class F1 : CN={f_pc[0]:.4f} | EMCI={f_pc[1]:.4f}")
print(f"\n{classification_report(y_true, y_pred, target_names=['CN','EMCI'], zero_division=0)}")

plt.figure(figsize=(4,3.2))
sns.heatmap(confusion_matrix(y_true, y_pred, labels=[0,1]), annot=True, fmt='d', cmap='Oranges',
            xticklabels=['CN','EMCI'], yticklabels=['CN','EMCI'])
plt.title("15-Model Val-Agirlikli — Test CM")
plt.xlabel("Tahmin"); plt.ylabel("Gercek"); plt.tight_layout(); plt.show()
# Out:
# 15 model agirligi (validation'dan, normalize):
#    Aksiyal   fold 1: 0.070
#    Aksiyal   fold 2: 0.038
#    Aksiyal   fold 3: 0.060
#    Aksiyal   fold 4: 0.081
#    Aksiyal   fold 5: 0.067
#    Koronal   fold 1: 0.052
#    Koronal   fold 2: 0.082
#    Koronal   fold 3: 0.065
#    Koronal   fold 4: 0.060
#    Koronal   fold 5: 0.053
#    Sagital   fold 1: 0.079
#    Sagital   fold 2: 0.066
#    Sagital   fold 3: 0.072
#    Sagital   fold 4: 0.091
#    Sagital   fold 5: 0.065
#
# ============================================================
# 15-MODEL VAL-AGIRLIKLI ENSEMBLE — NIHAI TEST
# ============================================================
#    Accuracy     : 0.6250
#    Precision    : 0.6434 | Recall: 0.6250 | F1: 0.6126
#    Per-Class F1 : CN=0.5432 | EMCI=0.6819
#
#               precision    recall  f1-score   support
#
#           CN       0.69      0.45      0.54       148
#         EMCI       0.59      0.80      0.68       148
#
#     accuracy                           0.62       296
#    macro avg       0.64      0.62      0.61       296
# weighted avg       0.64      0.62      0.61       296

# %%
try: SONUCLAR
except NameError: SONUCLAR = {'duzlem': {}, 'strateji': {}}
SONUCLAR['strateji']['15-model\nagirlikli'] = acc

# %%
# ===== GRAFIK: Val vs Test + Strateji Karsilastirmasi (otomatik) =====
import matplotlib.pyplot as plt
import numpy as np, pandas as pd, os

# Validation accuracy'leri CSV'den otomatik oku
duzlem_klasor = {
    'Sagital': os.path.join(ANA_KLASOR, 'Sagital', 'deney_sonuclari.csv'),
    'Aksiyal': os.path.join(ANA_KLASOR, 'Aksiyal', 'deney_sonuclari.csv'),
    'Koronal': os.path.join(ANA_KLASOR, 'Koronal', 'deney_sonuclari.csv'),
}
val_acc = {}
for ad, yol in duzlem_klasor.items():
    try: val_acc[ad] = pd.read_csv(yol)['val_acc'].mean()
    except Exception: val_acc[ad] = np.nan

# Test sonuclari SONUCLAR sozlugunden (test hucrelerinde otomatik dolduruldu)
test_acc_duzlem = SONUCLAR['duzlem']
strateji_test   = SONUCLAR['strateji']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5.5))

# Panel 1: Duzlem bazli Val vs Test
duzlemler = [d for d in ['Sagital','Aksiyal','Koronal'] if d in test_acc_duzlem]
x = np.arange(len(duzlemler)); w = 0.35
vd = [val_acc.get(d, np.nan) for d in duzlemler]
td = [test_acc_duzlem[d] for d in duzlemler]
b1 = ax1.bar(x - w/2, vd, w, label='Validation', color='#4C72B0')
b2 = ax1.bar(x + w/2, td, w, label='Test', color='#DD8452')
for bars in (b1, b2):
    for bar in bars:
        h = bar.get_height()
        if not np.isnan(h):
            ax1.text(bar.get_x()+bar.get_width()/2, h+0.008, f'{h:.3f}',
                     ha='center', va='bottom', fontsize=9)
ax1.axhline(0.5, color='gray', ls='--', lw=1, alpha=0.6)
ax1.set_xticks(x); ax1.set_xticklabels(duzlemler)
ax1.set_ylabel('Accuracy'); ax1.set_ylim([0.45, 0.80])
ax1.set_title('Duzlem Bazli: Validation vs Test\n(aradaki bosluk = genelleme acigi)')
ax1.legend(); ax1.grid(axis='y', alpha=0.3)

# Panel 2: Strateji bazli Test
stratejiler = list(strateji_test.keys())
ts = [strateji_test[s] for s in stratejiler]
renkler = ['#55A868' if v == max(ts) else '#C44E52' for v in ts]
bars = ax2.bar(stratejiler, ts, color=renkler, width=0.6)
for bar in bars:
    h = bar.get_height()
    ax2.text(bar.get_x()+bar.get_width()/2, h+0.004, f'{h:.3f}',
             ha='center', va='bottom', fontsize=10, fontweight='bold')
ax2.axhline(0.5, color='gray', ls='--', lw=1, alpha=0.6)
ax2.set_ylabel('Test Accuracy'); ax2.set_ylim([0.45, 0.72])
ax2.set_title('Birlestirme Stratejisi Karsilastirmasi (Test)\n(yesil = en iyi)')
ax2.grid(axis='y', alpha=0.3); plt.setp(ax2.get_xticklabels(), fontsize=9)

plt.tight_layout()
plt.savefig(os.path.join(ANA_KLASOR, 'val_test_karsilastirma.png'), dpi=120, bbox_inches='tight')
plt.show()
print("Kaydedildi:", os.path.join(ANA_KLASOR, 'val_test_karsilastirma.png'))
# Out:
# Kaydedildi: /content/drive/MyDrive/GizemZor/YAZILIM_TASARIMI/Bitirme/Dataset/models/DenseNet_PerPlane_Ensemble_YOL2_2026_06_04_21_36/val_test_karsilastirma.png
